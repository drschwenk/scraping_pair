# %% [markdown]
# # Table of Contents
# * &nbsp;
# 	* [Part 1: Using the PyMongo Client](#Part-1:-Using-the-PyMongo-Client)
# 	* [Part 2: Practice CSS Selectors](#Part-2:-Practice-CSS-Selectors)
# 	* [Part 3: Using a Web API to get meta data](#Part-3:-Using-a-Web-API-to-get-meta-data)
# 	* [Part 4: Scraping using the meta data](#Part-4:-Scraping-using-the-meta-data)
# 	* [Extra Credit](#Extra-Credit)
# 		* [User Login](#User-Login)
# 		* [Client side templating](#Client-side-templating)
# 		* [Automated Scraper](#Automated-Scraper)
# 		* [Proxy](#Proxy)

# %% [markdown]
# ## Part 1: Using the PyMongo Client

# %% [markdown]
# The PyMongo Client resembles Python much more than the Mongo shell we have dealt with this morning. In most applications, you will use PyMongo to interact with your Mongo Database as part of your data pipeline.
#
# 1. Use the follow snippet to start a Pymongo client and create a new collection (table) within a new database.
#
#    ```python
#    from pymongo import MongoClient
#    client = MongoClient()
#    # Initiate Database
#    db = client['test_database']
#    # Initiate Table
#    tab = db['test_table']
#    ```
# 2. Insert an entry into the collection you have initiated. Check if the entry is inserted from the mongo shell.
#    Query the inserted entry from Pymongo.
#
# 3. Try updating the entry you have inserted and verify that it has been updated.

# %%
from pymongo import MongoClient
client = MongoClient()
# Initiate Database
db = client['test_database']
# Initiate Table
tab = db['test_table']

# %%
tab.insert_one({'name': 'Ashley', 'age': '37'})

# %%
list(tab.find())
# Out:
# [{u'_id': ObjectId('564a588acbaf8f1876d9577f'),
#   u'age': u'37',
#   u'name': u'Ashley'}]

# %%
tab.update({
        "name": "Ashley"
    }, {
        "$set": {
            "age":"30"
        }
    }
          )
# Out:
# {u'n': 1, u'nModified': 1, u'ok': 1, 'updatedExisting': True}

# %%
list(tab.find())
# Out:
# [{u'_id': ObjectId('564a588acbaf8f1876d9577f'),
#   u'age': u'30',
#   u'name': u'Ashley'}]

# %% [markdown]
# ## Part 2: Practice CSS Selectors

# %% [markdown]
# CSS selectors are an important part of web scraping as they allow you to select content on a web page. Refer to
# this [CSS Cheatsheet](http://www.cheetyr.com/css-selectors) if you need a reminder of the CSS selectors that are available to you.
# The best way to test out CSS selectors is to use the `Inspect Element` tool in the Google Chrome browser. We will
# walk through the work flow in the exercise below.
#
# 1. Open up `data/ebay_shoes.html` with Google Chrome. It should be as shown below.
#
#    ![image](pics/first_image.png)
#
# 2. Right click on the first shoe image and click `Inspect Element` to bring up a panel, as seen below.
#
#    ![image](pics/second_image.png)
#
# 3. Construct a CSS select that would allow you to select every shoe image on the page.
#    The CSS selector should be referring to the `img` tag of a particular class.
#    Click `Console` to switch to the console mode. Select the CSS selector by entering into the console
#    `$('your css selector')`. Hover over one of the selected elements, it should be as seen below.
#
#    ![image](pics/third_image.png)
#
# 4. Open up IPython in your terminal and import BeautifulSoup4 with the line `from bs4 import BeautifulSoup`.
#    Read `data/ebay_shoes.html` in as one string from the file and put it into a `BeautifulSoup()` with the
#    line `soup = BeautifulSoup(html_str, 'html.parser')`.
#
#    You should be able to use the CSS selector on the soup using `soup.select('your css selector')`. It will
#    then return a list of tags that each contains the source of the image location. Create a list of the paths to the    image locations by looping through the tags and accessing the image path by `tag['src']`.
#
# 5. Open the file paths and read the files in as string. Write them to a new directory named `images`. Open the
#    files in the `images` directory to ensure the images are saved properly.
#
# 6. This is the basic work flow of web scraping with CSS selectors. Realistically you would not be reading in a local
#    html file, but read the html file from a link instead. Go to ebay, search for your a product of your choice and
#    copy the link. Use the `get` function in the [`requests` library](http://docs.python-requests.org/en/latest/)
#    to retrieve the html. The `get` function returns a response where `response.content` returns the html as a
#    string.
#
# 7. Retrieve the product descriptions from your selected page by following the web scraping work flow.

# %% [markdown]
# $('.imgWr2') selects all the images

# %%
from bs4 import BeautifulSoup

# %%
pwd
# Out:
# u'/Users/loribeerman/Documents/galvanize/Week5/web-scraping/scraping_pair'

# %%
f = open('data/ebay_shoes.html', 'r')

# %%
soup = BeautifulSoup(f, 'html.parser')

# %%
    
#to view attributes:   
#dir(soup.select('.imgWr2')[0])

#soup.select('.imgWr2').findall('src')
img_list = []
for img in soup.find_all('img'):
    img_list.append(img['src'])
    
#img_list

# %%
center = soup.find("div", {"id": "Center"})

# %%
src_list = []
for img in soup.select('.imgWr2'):
    src_list.append(img.find('img')['src'])
    
#src_list

# %%
#center.findAll('img')

# %%
mkdir images

# %%
ls data
# Out:
# click_log.json      coffee-tweets.json  ebay_shoes.html     ebay_shoes_files/   variety.js

# %%
mkdir images/ebay_shoes_files

# %%
for img in src_list:
    f = open('./data/' +str(img), 'rb')
    f2 = open('./images/' +str(img), 'wb')
    f2.write(f.read())
    f.close()
    f2.close()

# %%
ls images/ebay_shoes_files/
# Out:
# 121612297064_1.jpg           261827105853_1.jpg           mJtUO8zZhjwQzjqh3arZ6BA.jpg  mnsC4wTn7E8hXnQgzMiMaqw.jpg
# 171659641420_3.jpg           330938242122_4.jpg           mUpyhvMcfYrElFiMBEqXHmg.jpg  mwiFWleobXkPHMEGM5_9ptQ.jpg
# 191550477937_1.jpg           m8XeN04c02pW40nMvmDcOlA.jpg  mbiSFaOF_X42DyluIbWy-eA.jpg  mykGgapI1PTZi058nlo-pyw.jpg
# 191550485767_1.jpg           m8jwonhvkNHPxBswK4mJQOw.jpg  mjhj6cMGXtEpGrxVN96CCfg.jpg  s_1x2(1).gif
# 191550487568_1.jpg           mA7jJs2pEcZ5LufNvDmGVkw.jpg  mlb-QMQYQ-tAzs0PuvwMrGA.jpg
# 260976810161_2.jpg           mCf1peFbkB6cW8cpCB394pQ.jpg  mmXil7R_hLf4Gnd9EhfzD3g.jpg

# %%
import requests

# %%
url = 'http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?hash=item542621c5cc:g:n68AAOSwA4dWLp4b'
r = requests.get(url)

# %%
tree_soup = BeautifulSoup(r.content, 'html.parser')

# %%
tree_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <!--  fix for IE freezing.  -->
# <style type="text/css">
# body #Body .btn, body #Body c-std {
# filter:none;
# -ms-filter: "progid:DXImageTransform.Microsoft.gradient(startColorstr='#0079bc',endColorstr='#00509d')";
# }
# </style>
# <meta name="viewport"/>
# <meta content="main" name="layout"/>
# <!-- Use ?ForceSiteSpeedGauge=true for forcing -->
# <link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=SV" hreflang="es-sv" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=GT" hreflang="es-gt" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=HN" hreflang="es-hn" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=CO" hreflang="es-co" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=CR" hreflang="es-cr" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=BO" hreflang="es-bo" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=NI" hreflang="es-ni" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=PR" hreflang="es-pr" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=AR" hreflang="es-ar" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=PY" hreflang="es-py" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=CL" hreflang="es-cl" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=PA" hreflang="es-pa" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=EC" hreflang="es-ec" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=VE" hreflang="es-ve" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=MX" hreflang="es-mx" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=RU" hreflang="ru-ru" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=BR" hreflang="pt-br" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=DO" hreflang="es-do" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=PE" hreflang="es-pe" rel="alternate"/><link href="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396?_ul=UY" hreflang="es-uy" rel="alternate"/><meta content="eBay" property="og:site_name"/><meta content="6e11485a66d91eff" name="yandex-verification"/><meta content="http://www.ebay.com/soc/guckrdt?itm=361417000396&amp;tcclocation=buybutton&amp;requestURL=http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396" name="twitter:url:purchase_url"/><meta content="US $99.95" name="twitter:text:price"/><meta content="8kHr3jd3Z43q1ovwo0KVgo_NZKIEMjthBxti8m8fYTg" name="google-site-verification"/><title> Pre Lit Fiber Optic 7&amp;apos; Artificial ...
# <!--[if lt IE 8]>
# 		<![endif]-->
# <!-- adding lens js -->
# <link href="http://ir.ebaystatic.com/rs/v/v3w53524yu4qtmefvindqlprou4.css?proc=DU:N" rel="stylesheet" type="text/css"><link href="http://ir.ebaystatic.com/rs/v/3ptwpgki3u5exbibjv44tqeehim.css?proc=DU:N" rel="stylesheet" type="text/css"><link href="http://ir.ebaystatic.com/rs/v/hx2difr5ha5ddbzrminyuyuw2my.css?proc=DU:N" rel="stylesheet" type="text/css"><style type="text/css">body .is.vi-ppc-main .mm-dp {
# width:35%;
# }
#
# #vi-snippet-description-main.u-padB20 {
#     padding-top:10px;
#     float:left;
# }
#
# .vi-descsnpt-feedbacklnk {
#     position: relative;
#     top: -20px;
#     width: 500px;
#     margin-left: 250px;
# }
#
# .asqMain {
#     clear:both;
# }
#
# div#bsi-c {
# clear: both;
# }
# .vi-pco-bboxtxt-Ins * {
# 	font-weight: normal !important;
# 	color: #0654ba !important;
# }</style><style type="text/css">
# 				html a:link{
# 					color: #0654ba;
# 				}
# 				ul#bc a:link{
# 					color: #0654ba;
# 				}
# 				.mbg a:link{
# 					color: #0654ba !important;
# 				}
# 				.mbg-l a:link{
# 					color: #0654ba !important;
# 				}
# 				#Body .nav-tabs-m a:link{
# 					color: #0654ba;
# 				}
# 			</style>
# </link></link></link></head>
# <body class=" vi-contv2 lhdr-ie- vi-hd-ops ">
# <!-- Default filmstrip js used with main image -->
# <!-- adding filmstrip js used in main pic and with images carousel  -->
# <div id="Head">
# </div>
# <div class=" sz940 " id="Body" itemscope="itemscope" itemtype="http://schema.org/Product">
# <div id="TopPanelDF"><div id="Top">
# <div id="TopPanel">
# <style>.gh-hide-if-nocss{display:none;}</style> <!--[if lt IE 9]><link rel="stylesheet" type="text/css" href="http://ir.ebaystatic.com/rs/v/32q2wauokmyjletm4byq40w5s2i.css?proc=DU:N"></link><![endif]--><div class="gh-acc-exp-div"><a class="gh-acc-a" href="#mainContent" id="gh-hdn-stm">Skip to main content</a></div><!--[if lt IE 9]><div id="gh" role="banner" class="gh-IE8 gh-flex gh-pre-js gh-w "><![endif]--><!--[if (gte IE 9)|!(IE)]><!--><header class="gh-flex gh-pre-js gh-w " id="gh" role="banner"><!--<![endif]--><table class="gh-tbl"><tbody><tr><td class="gh-td"><!--[if lt IE 9]><a href="http://www.ebay.com/" _sp="m570.l2586" id="gh-la">eBay<img role="presentation" width=117 height=120 style='clip:rect(47px, 118px, 95px, 0px); position:absolute; top:-47px;left:0' alt="" src="http://ir.ebaystatic.com/rs/v/apstidvcvu5pxlbxkphrrdo5iqv.png" id="gh-logo"></a><![endif]--><!--[if (gte IE 9)|!(IE)]><!--><a _sp="m570.l2586" href="http://www.ebay.com/" id="gh-la">eBay<img alt="" height="200" id="gh-logo" role="presentation" src="http://ir.ebaystatic.com/rs/v/fxxj3ttftm5ltcqnto1o4baovyl.png" style="clip:rect(47px, 118px, 95px, 0px); position:absolute; top:-47px;left:0" width="250"/></a><!--<![endif]--></td><td class="gh-td"><div id="gh-shop"><button aria-controls="gh-sbc-o" aria-expanded="false" class="gh-control" id="gh-shop-a">Shop by category<i class="gh-sprRetina" id="gh-shop-ei"></i></button><div id="gh-sbc-o"></div></div></td><td class="gh-td-s"><form action="http://www.ebay.com/sch/i.html" id="gh-f" method="get"><input name="_from" type="hidden" value="R40"><input name="_trksid" type="hidden" value="m570.l1313"><table class="gh-tbl2"><tbody><tr><td class="gh-td-s"><div id="gh-ac-box"><div id="gh-ac-box2"><label class="gh-ar-hdn" for="gh-ac">Enter your search keyword</label><input autocapitalize="off" autocomplete="off" autocorrect="off" class="gh-tb ui-autocomplete-input" id="gh-ac" maxlength="300" name="_nkw" placeholder="Search..." size="50" spellcheck="false" type="text"/></div></div></td><td class="gh-td" id="gh-cat-td"><div id="gh-cat-box"><select class="gh-sb gh-sprRetina" id="gh-cat" name="_sacat" size="1" title="Select a category for search"><option selected="selected" value="0">All Categories</option></select></div></td><td class="gh-td"><input class="btn btn-ter gh-spr" id="gh-btn" type="submit" value="Search"/></td><td class="gh-td" id="gh-as-td"><a _sp="m570.l2614" href="http://www.ebay.com/sch/ebayadvsearch" id="gh-as-a" title="Advanced Search">Advanced</a></td></tr></tbody></table></input></input></form></td></tr></tbody></table><div id="gh-top"><ul id="gh-topl"><li class="gh-t gh-spr " id="gh-eb-u"><script>(function(){try{var d=document.cookie,a=((a=d.match(/u1f[^a-zA-Z0-9]([^^]*)[0-9a-z]{8}/))?a[1].replace(/\+/g," "):"").replace(/(.{12}).*/,"$1...");if(/[<>%&'\/]/.test(a)){throw(1)}document.write("<span id=gh-ug"+(!a||/u1p.QEBfX/.test(d)?' class=gh-ug-guest>Hi! <a href="https://signin.ebay.com/ws/eBayISAPI.dll?SignIn&amp;_trksid=m570.l1524" rel="nofollow" _sp="m570.l1524">Sign in</a> <span id="gh-ug-flex">or <a href="https://reg.ebay.com/reg/PartialReg?_trksid=m570.l2621" rel="nofollow" _sp="m570.l2621">register</a></span>':' style="margin-right:3px">Hi <b>-User-</b>!'.replace(/-User-/,escape(a)))+"</span>")}catch(b){document.write("<style>#gh-topl{display:none}</style>")}})();</script><noscript class="gh-t gh-spr">Hi (<a href="https://signin.ebay.com/ws/eBayISAPI.dll?SignIn&amp;_trksid=m570.l3348">Sign in</a> to bid or buy)</noscript></li><li class="gh-t gh-spr " id="gh-p-1"><a _sp="m570.l3188" class="gh-p" href="http://deals.ebay.com/">Daily Deals</a></li><li class="gh-t gh-spr " id="gh-p-4"><a _sp="m570.l6463" class="gh-p" href=" http://www.ebay.com/rpp/gift-cards">Gift Cards</a></li><li class="gh-t gh-spr " id="gh-p-2"><a _sp="m570.l1528" class="gh-p" href="http://csr.ebay.com/cse/sell.jsf">Sell</a></li><li class="gh-t gh-spr " id="gh-p-3"><a _sp="m570.l1545" class="gh-p" href="http://ocs.ebay.com/ws/eBayISAP ...
# <div class="vi-bc-svySpn" style="float:right;">
# <span id="w1-2">
# <a href="javascript:void(0)" id="surveylink" rel="nofollow">
# </a>
# </span>
# </div>
# <ul id="bc">
# <table class="">
# <tr>
# <td class="vi-VR-bkto-TD" nowrap="nowrap" style="vertical-align:top;">
# <li id="smtBackToAnchorArrow" style="">
# <span class="gspr vi-bkto-arrnewred" style=""> </span>
# </li>
# </td>
# <td class="vi-VR-bkto-TD" nowrap="nowrap" style="vertical-align:top;">
# <li id="vi-brumb-frstCol" style=""><a class="vi-VR-spl-lnk" href="http://www.ebay.com" id="smtBackToAnchor" style="padding-right:1px;" title="Click to Go Back to home page">Back to home page</a></li>
# <!--[if lt IE 8]>
# 			  	<li  style="margin:0px 5px 0px -10px"  id="vi-VR-brumb-pipeIcon">|</li>
# 			 <![endif]-->
# </td>
# <td id="vi-VR-brumb-pdplnkLst" nowrap="nowrap" style="vertical-align:top;">
# <li style="margin-right:5px;width:100%; "><span aria-hidden="true" style="margin:0px 5px 0px -10px">|</span>Listed in category: </li>
# </td>
# <td class="vi-VR-brumblnkLst vi-VR-brumb-hasNoPrdlnks" id="vi-VR-brumb-lnkLst" style="vertical-align:top;">
# <table width="100%">
# <tr><td style="">
# <h2>
# <ul itemscope="" itemtype="http://schema.org/Breadcrumblist">
# <li class="bc-w" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a _sp="p2047675.l2706" class="thrd" href="http://www.ebay.com/sch/Home-Garden-/11700/i.html" itemprop="item"><span itemprop="name">Home &amp; Garden</span></a></li>
# <meta content="javax.servlet.jsp.jstl.core.LoopTagSupport$1Status@6d9b5397" itemprop="position">
# <li>&gt;</li>
# <li class="bc-w" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a _sp="p2047675.l2706" class="thrd" href="http://www.ebay.com/sch/Holiday-Seasonal-Decor-/38227/i.html" itemprop="item"><span itemprop="name">Holiday &amp; Seasonal Décor</span></a></li>
# <meta content="javax.servlet.jsp.jstl.core.LoopTagSupport$1Status@6d9b5397" itemprop="position">
# <li>&gt;</li>
# <li class="bc-w" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a _sp="p2047675.l2706" class="thrd" href="http://www.ebay.com/sch/Christmas-Winter-/170090/i.html" itemprop="item"><span itemprop="name">Christmas &amp; Winter</span></a></li>
# <meta content="javax.servlet.jsp.jstl.core.LoopTagSupport$1Status@6d9b5397" itemprop="position">
# <li>&gt;</li>
# <li class="bc-w" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a _sp="p2047675.l2706" class="scnd" href="http://www.ebay.com/sch/Artificial-Christmas-Trees-/117414/i.html" itemprop="item"><span itemprop="name">Artificial Christmas Trees</span></a></li>
# <meta content="javax.servlet.jsp.jstl.core.LoopTagSupport$1Status@6d9b5397" itemprop="position">
# </meta></meta></meta></meta></ul>
# </h2>
# </td></tr>
# </table>
# </td>
# </tr>
# </table>
# </ul>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div><div id="CenterPanelDF"><div class=" ebaylocale_en_US ebay_longlngsite " id="CenterPanel">
# <style>
# /* PicturePanel */
# #PicturePanel div.img {
# 	border:1px solid #ccc;
# 	background-color:white;
# }
# /* BuyBox */
# .actPanel  {
# 	border-top:1px solid #ccc;
# 	border-left:1px solid #ccc;
# 	border-right:1px solid #ccc;
# }
# .watchListCmp {
# 	border-bottom:1px solid #ccc;
# 	border-left:1px solid #ccc;
# 	border-right:1px solid #ccc;
# }
# </style>
# <h3 class="vi-inheritstyl">
# <div class="tmpnl">
# <div class="pnl u-dspn" id="msgPanel">
# <div class="msg ">
# <div aria-atomic="true" aria-live="assertive" aria-relevant="all" class="msgPad ">
# <span class="statusContent">
# <span class="statusLeftContent">
# <span class="msgTextAlign" id="w1-4-_msg"></span>
# </span>
# <span class="statusRightContent">
# </span>
# <div style="clear: both;"></div>
# </span>
# </div>
# </div>
# </div><div>
# <!-- Removed welcome messages as no longer displayed -->
# <!-- CHECK if still shown on VI : Parent action Text : check how to display -->
# <!-- CHECK if still shown on VI :  -->
# <!-- IF Display Natural Search welcome message 2 is available : show that message
# 			 ELSE check if ItemTitle is available format (Item: ItemTitle) -->
# <!-- Show Variation details, VariationPrice, VariationQuantity -->
# </div>
# <div id="listingHistory"></div><div id="otherMsg"></div></div>
# </h3>
# <div class="vi-sme-ss-v1" id="vi_sme_prmts_bnr_cntr1">
# <div class="dli-mb12" id="promotionBanner">
# <span class="smeOfferIcon" style="background-image:url(http://ir.ebaystatic.com/f/dr4fawrazi2bjohk51calwv1nab.png)"></span>
# <a class="smeOfferMsg" href="http://www.ebay.com/sme/bestchoiceproducts/Buy-2-get-1-at-10-off/so.html?_soffid=5001555102&amp;_soffType=OrderSubTotalOffer&amp;_trksid=p2047675.m2197">BUY 2, GET 1 AT <span style="COLOR:#5B9D78">10%</span> OFF (add 3 to cart)</a>
# <a class="smeOfferLink" href="http://www.ebay.com/sme/bestchoiceproducts/Buy-2-get-1-at-10-off/so.html?_soffid=5001555102&amp;_soffType=OrderSubTotalOffer&amp;_trksid=p2047675.m2197">
# <span class="vi-smev2-hide">See all eligible items</span>
# <img alt="See all eligible items" border="0" height="8" src="http://ir.ebaystatic.com/pictures/aw/pics/sellerTools/iconSME-Arrow-6x8.png" style="margin-left:5px;" width="6">
# </img></a>
# </div>
# </div>
# <!--  Placement 100005 -->
# <!-- Placement 100011 && 100012 -->
# <div class="" id="CenterPanelInternal">
# <div class="pp-c" id="PicturePanel">
# <h3 class="g-hdn">Picture Information</h3>
# <div class="pp-ic pp-ic300">
# <div class="l-shad lftd img img300">
# <table class="img img300">
# <tbody>
# <tr>
# <td class="img img300">
# <div id="test"><!-- test --></div><script type="text/javascript">var sPT = new Date().getTime(),picTimer,picTimer1,picTimer2;</script>
# <a href="javascript:;" id="linkMainImg" style="display: block; cursor: default; text-decoration: none;">
# <div class="" id="mainImgHldr" style="width:300px" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <!-- <span id="mainImgHldr" style="display: inline-block;"> -->
# <img alt="Image is loading" class="img img300 vi-hide-mImgThr" id="icThrImg" imgsel="0" src="http://ir.ebaystatic.com/pictures/aw/pics/globalAssets/imgLoading_30x30.gif" style="display:none;"/>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" class="img img300" clk="" id="icImg" itemprop="image" onload="picTimer=new Date().getTime();" src="http://i.ebayimg.com/images/g/n68AAOSwA4dWLp4b/s-l300.jpg" style=""/>
# <!-- </span> -->
# </div>
# </a>
# <span class="imgNa" id="imgNATxt">Image not available</span>
# <span class="imgNa" id="varImgNATxt" style="display:none">Photos not available for this variation</span>
# <noscript><style type="text/css">.vi-hide-mImgThr {display: none;}</style><img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" class="img img300" clk="" id="icImg" itemprop="image" src="http://i.ebayimg.com/images/g/n68AAOSwA4dWLp4b/s-l300.jpg" style=""/></noscript>
# <script type="text/javascript">
# 							function picOnLoad(isSetClkId){
# 								var elem = document.getElementById('icThrImg');
# 								var pic = document.getElementById('icImg');
# 								elem.style.display = 'none';
# 								pic.style.display = '';
# 								if(isSetClkId) {
# 									pic.setAttribute('clk', elem.getAttribute('imgsel'));
# 								}
# 								document.getElementById('imgNATxt').style.display = 'none';
# 								document.getElementById('mainImgHldr').style.backgroundImage = 'none';
# 								return;
# 							}
# 							function picOnError(){
# 								var elemThr = document.getElementById('icThrImg');
# 								var pic = document.getElementById('icImg');
# 								elemThr.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';
# 								elemThr.style.display = '';
# 								pic.style.display = 'none';
# 								pic.setAttribute('clk', elemThr.getAttribute('imgsel'));
# 								document.getElementById('imgNATxt').style.display = 'block';
# 								document.getElementById('mainImgHldr').style.backgroundImage = 'none';
# 								return;
# 							}
# 							var image = document.createElement('img');
# 							image.src=  'http://i.ebayimg.com/images/g/n68AAOSwA4dWLp4b/s-l300.jpg';
# 							if(image.complete ||  image.readyState === 4){
# 								picTimer2=new Date().getTime();
# 								picOnLoad(true);
# 							}else{
# 							    image.onload = function(){
# 							    	picTimer1=new Date().getTime();
# 							    	picOnLoad(true);
# 							    };
# 							    image.onerror = function(){
# 									picOnError();
# 								};
# 							}
# 							image.onerror = function(){
# 								picOnError();
# 							};
# 						</script>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="spr"></div>
# <div class="u-cb" style="height:20px;"></div>
# <div class="pt-p" id="zoom_enlarge_msg_cnt" style="visibility:hidden;">
# <span class="pt-i pt-tx " href="javascript:;" id="zoom_enlarge_msg"></span>
# </div>
# <div class="zoom_trigger_mask" id="vi_zoom_trigger_mask">
# <div id="vi_zoom_trigger_mrk">
# <div class="vi_zoom_trigger_msg">
# <table>
# <tr>
# <td><b style="display: block; font-family: 'Helvetica neue',Helvetica,Arial,Verdana,Sans-serif; font-size: 12px;">Mouse over to Zoom<br>-<br>Click to enlarge</br></br></b></td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <span class="zoom_slct" id="zoom_selector"></span>
# <div class="zoom_mask" id="zoom_img_mask"></div>
# <div class="zoom_cntr" id="zoom_main_cntr">
# <div class="zoom_img_cntr" id="zoom_main_img_cntr">
# <img alt="" id="zoom_main_img" src="http://ir.ebaystatic.com/pictures/aw/pics/s.gif" style="display: none;">
# </img></div>
# </div>
# <div class="vi_pl_panel" id="viEnlargeImgLayer">
# <button class="vi_pl_cls_btn">X</button>
# <div class="vi_img_crsl_cmp">
# <div class="vi_img_crsl_imgpl ">
# <a aria-label="To Previous Image" class="pntrArr pntrArrPrev pntrArrImg activePrev" href="javascript:;" title="To Previous Image"></a>
# <table class="vi_img_crsl_tbl">
# <tbody>
# <tr>
# <td class="vi_img_crsl_tbl">
# <div class="vi_img_crsl_ctr"><img alt="" clk="" id="viEnlargeImgLayer_img_ctr" src="http://ir.ebaystatic.com/pictures/aw/pics/s.gif"/></div>
# </td>
# </tr>
# </tbody>
# </table>
# <a aria-label="To Next Image" class="pntrArr pntrArrNext pntrArrImg activeNext" href="javascript:;" title="To Next Image"></a>
# </div>
# </div>
# <div class="vi_img_crsl_fspl_trg">
# <div class="vi_img_crsl_fspl vi_crsl_fspl_blk">
# <div style="width:100%; padding-top: 15px;">
# <div class="vi-filmstp" id="viEnlargeImgLayer_layer_fs_slider" style="width:300px">
# <a class="gspr flm-btn pre " href="javascript:;"></a>
# <div class="fs_imgc" id="viEnlargeImgLayer_layer_fs" style="">
# <ul class="lst icon">
# <li>
# <a class="pic pic1" href="javascript:;" id="viEnlargeImgLayer_layer_fs_thImg0" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <table class="img">
# <tr>
# <td class="tdThumb" style="height:64px; ">
# <div>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" index="0" onerror="try{this.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';}catch(e){}" src="http://i.ebayimg.com/images/g/n68AAOSwA4dWLp4b/s-l64.jpg" style="max-width:64px;max-height:64px"/>
# </div>
# </td>
# </tr>
# </table>
# </a>
# </li>
# <li>
# <a class="pic pic1" href="javascript:;" id="viEnlargeImgLayer_layer_fs_thImg1" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <table class="img">
# <tr>
# <td class="tdThumb" style="height:64px; ">
# <div>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" index="1" onerror="try{this.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';}catch(e){}" src="http://i.ebayimg.com/images/g/7HMAAOSwT4lWRoQX/s-l64.jpg" style="max-width:64px;max-height:64px"/>
# </div>
# </td>
# </tr>
# </table>
# </a>
# </li>
# <li>
# <a class="pic pic1" href="javascript:;" id="viEnlargeImgLayer_layer_fs_thImg2" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <table class="img">
# <tr>
# <td class="tdThumb" style="height:64px; ">
# <div>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" index="2" onerror="try{this.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';}catch(e){}" src="http://i.ebayimg.com/images/g/xtcAAOSwlV9WRoQX/s-l64.jpg" style="max-width:64px;max-height:64px"/>
# </div>
# </td>
# </tr>
# </table>
# </a>
# </li>
# <li>
# <a class="pic pic1" href="javascript:;" id="viEnlargeImgLayer_layer_fs_thImg3" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <table class="img">
# <tr>
# <td class="tdThumb" style="height:64px; ">
# <div>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" index="3" onerror="try{this.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';}catch(e){}" src="http://i.ebayimg.com/images/g/NcoAAOSwiwVWRoQa/s-l64.jpg" style="max-width:64px;max-height:64px"/>
# </div>
# </td>
# </tr>
# </table>
# </a>
# </li>
# <li>
# <a class="pic pic1" href="javascript:;" id="viEnlargeImgLayer_layer_fs_thImg4" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <table class="img">
# <tr>
# <td class="tdThumb" style="height:64px; ">
# <div>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" index="4" onerror="try{this.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';}catch(e){}" src="http://i.ebayimg.com/images/g/PisAAOSwMTZWRoQY/s-l64.jpg" style="max-width:64px;max-height:64px"/>
# </div>
# </td>
# </tr>
# </table>
# </a>
# </li>
# <li>
# <a class="pic pic1" href="javascript:;" id="viEnlargeImgLayer_layer_fs_thImg5" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <table class="img">
# <tr>
# <td class="tdThumb" style="height:64px; ">
# <div>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" index="5" onerror="try{this.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';}catch(e){}" src="http://i.ebayimg.com/images/g/7IwAAOSwT4lWRoQY/s-l64.jpg" style="max-width:64px;max-height:64px"/>
# </div>
# </td>
# </tr>
# </table>
# </a>
# </li>
# </ul>
# </div>
# <a class="gspr flm-btn nxt " href="javascript:;"></a>
# <div class="sel hide"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="vi-filmstp" id="vi_main_img_fs_slider" style="width:300px">
# <a class="gspr flm-btn pre " href="javascript:;"></a>
# <div class="fs_imgc" id="vi_main_img_fs" style="height:77px; width:226px">
# <ul class="lst icon">
# <li>
# <a class="pic pic1" href="javascript:;" id="vi_main_img_fs_thImg0" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <table class="img">
# <tr>
# <td class="tdThumb" style="height:64px; ">
# <div>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" index="0" onerror="try{this.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';}catch(e){}" src="http://i.ebayimg.com/images/g/n68AAOSwA4dWLp4b/s-l64.jpg" style="max-width:64px;max-height:64px"/>
# </div>
# </td>
# </tr>
# </table>
# </a>
# </li>
# <li>
# <a class="pic pic1" href="javascript:;" id="vi_main_img_fs_thImg1" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <table class="img">
# <tr>
# <td class="tdThumb" style="height:64px; ">
# <div>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" index="1" onerror="try{this.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';}catch(e){}" src="http://i.ebayimg.com/images/g/7HMAAOSwT4lWRoQX/s-l64.jpg" style="max-width:64px;max-height:64px"/>
# </div>
# </td>
# </tr>
# </table>
# </a>
# </li>
# <li>
# <a class="pic pic1" href="javascript:;" id="vi_main_img_fs_thImg2" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <table class="img">
# <tr>
# <td class="tdThumb" style="height:64px; ">
# <div>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" index="2" onerror="try{this.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';}catch(e){}" src="http://i.ebayimg.com/images/g/xtcAAOSwlV9WRoQX/s-l64.jpg" style="max-width:64px;max-height:64px"/>
# </div>
# </td>
# </tr>
# </table>
# </a>
# </li>
# <li>
# <a class="pic pic1" href="javascript:;" id="vi_main_img_fs_thImg3" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <table class="img">
# <tr>
# <td class="tdThumb" style="height:64px; ">
# <div>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" index="3" onerror="try{this.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';}catch(e){}" src="http://i.ebayimg.com/images/g/NcoAAOSwiwVWRoQa/s-l64.jpg" style="max-width:64px;max-height:64px"/>
# </div>
# </td>
# </tr>
# </table>
# </a>
# </li>
# <li>
# <a class="pic pic1" href="javascript:;" id="vi_main_img_fs_thImg4" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <table class="img">
# <tr>
# <td class="tdThumb" style="height:64px; ">
# <div>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" index="4" onerror="try{this.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';}catch(e){}" src="http://i.ebayimg.com/images/g/PisAAOSwMTZWRoQY/s-l64.jpg" style="max-width:64px;max-height:64px"/>
# </div>
# </td>
# </tr>
# </table>
# </a>
# </li>
# <li>
# <a class="pic pic1" href="javascript:;" id="vi_main_img_fs_thImg5" title="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand">
# <table class="img">
# <tr>
# <td class="tdThumb" style="height:64px; ">
# <div>
# <img alt="Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand" index="5" onerror="try{this.src='http://p.ebaystatic.com/aw/pics/cmp/icn/iconImgNA_96x96.gif';}catch(e){}" src="http://i.ebayimg.com/images/g/7IwAAOSwT4lWRoQY/s-l64.jpg" style="max-width:64px;max-height:64px"/>
# </div>
# </td>
# </tr>
# </table>
# </a>
# </li>
# </ul>
# </div>
# <a class="gspr flm-btn nxt " href="javascript:;"></a>
# <div class="sel hide"></div>
# </div>
# </div>
# <div class="vi-pbh" style="margin-top:10px;">
# <table class="vi-centerclass">
# <tr>
# <td style="text-align:centervertical-align:top;" width="">
# <div class="vi-slt-c vi-slt-instSale-us">
# <i></i><b>Have one to sell?</b>
# <span>
# <span id="inst_sale_btn_parent">
# <a _sp="p2047675.l2567" class="btn btn-ter btn-m " href="http://cgi5.ebay.com/ws/eBayISAPI.dll?SellLikeItem&amp;item=361417000396&amp;rt=nc&amp;_trksid=p2047675.l2567" id="inst_sale_btn" rel="nofollow" role="button" style="">
# 									Sell now</a>
# </span>
# </span>
# </div>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <div style="">
# <h1 class="it-ttl" id="itemTitle" itemprop="name"><span class="g-hdn">Details about   </span>Pre-Lit Fiber Optic 7' Artificial Christmas Tree LED Multicolor Lights and Stand</h1>
# <!-- DO NOT change linkToTagId="rwid" as the catalog response has this ID set  -->
# <div class="vi-notify-new-bg-wrapper" style="">
# <div class="vi-notify-new-bg-dTop" style=""> </div>
# <div class="vi-notify-new-bg-dBtm" id="vi_notification_new">
# <img alt="Popular" class="vi-notify-new-img" height="12" src="http://ir.ebaystatic.com/rs/v/tnj4p1myre1mpff12w4j1llndmc.png" width="11"/>
# <span style="font-weight:bold;">4 sold in last hour</span>
# </div>
# </div>
# </div>
# <div class="it-rlBr it-rlBr300 " style="">
# </div>
# <span class="u-dspn" id="vi-lkhdr-itmTitl">Pre-Lit Fiber Optic 7' Artificial Christmas Tree LED Multicolor Lights and Stand</span>
# <div class="rsp-c" id="RightSummaryPanel">
# <div class="share si-cnt no-flt " style="z-index:10;position: absolute; display:block; width: 400px; right: 0px;margin-top:-25px;clear:both;">
# <table align="right" class=" ">
# <tr>
# <td>
# <div class="social-widget">
# <div class="sw">
# <a aria-label="Email to friends" class="scIcon sw_email" data-destination="email" data-itemid="361417000396" data-language="en_US" data-spid="2047675" etafsharetitle="Pre-Lit Fiber Optic 7' Artificial Christmas Tree LED Multicolor Lights and Stand" etafshareurl="http://www.ebay.com/itm/Pre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-/361417000396" href="javascript:;" id="sc_email" rel="nofollow" title="Email to friends"></a>
# <a aria-label="Share on Facebook - opens in a new window or tab" class="scIcon sw_facebook" data-destination="facebook" data-tracking="" href="http://www.ebay.com/soc/share?du=http%3A%2F%2Fwww.ebay.com%2Fitm%2FPre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-%2F361417000396&amp;rt=nc&amp;t=Pre-Lit+Fiber+Optic+7%27+Artificial+Christmas+Tree+LED+Multicolor+Lights+and+Stand&amp;spid=2047675&amp;itm=361417000396&amp;media=http%3A%2F%2Fgalleryplus.ebayimg.com%2Fws%2Fweb%2F361417000396_1_0_1%2F1000x1000.jpg&amp;swd=2&amp;shorten=0" rel="nofollow" target="_blank" title="Share on Facebook - opens in a new window or tab"></a>
# <a aria-label="Share on Twitter - opens in a new window or tab" class="scIcon sw_twitter" data-destination="twitter" data-tracking="" href="http://www.ebay.com/soc/share?du=http%3A%2F%2Fwww.ebay.com%2Fitm%2FPre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-%2F361417000396&amp;rt=nc&amp;spid=2047675&amp;itm=361417000396&amp;media=http%3A%2F%2Fgalleryplus.ebayimg.com%2Fws%2Fweb%2F361417000396_1_0_1%2F1000x1000.jpg&amp;swd=3&amp;lang=en&amp;t=Check+out+Pre-Lit+Fiber+Optic+7%27+Artificial+Christmas+Tree+LED+Multicolor+Lights+and+Stand" rel="nofollow" target="_blank" title="Share on Twitter - opens in a new window or tab"></a>
# <a aria-label="Share on Pinterest - opens in a new window or tab" class="scIcon sw_pinterest" data-destination="pinterest" data-tracking="" href="http://www.ebay.com/soc/share?du=http%3A%2F%2Fwww.ebay.com%2Fitm%2FPre-Lit-Fiber-Optic-7-Artificial-Christmas-Tree-LED-Multicolor-Lights-and-Stand-%2F361417000396&amp;rt=nc&amp;spid=2047675&amp;itm=361417000396&amp;media=http%3A%2F%2Fgalleryplus.ebayimg.com%2Fws%2Fweb%2F361417000396_1_0_1%2F1000x1000.jpg&amp;swd=11&amp;t=Pre-Lit+Fiber+Optic+7%27+Artificial+Christmas+Tree+LED+Multicolor+Lights+and+Stand" rel="nofollow" target="_blank" title="Share on Pinterest - opens in a new window or tab"></a>
# </div>
# </div>
# </td>
# <td>
# <div class=" watchLnk ">
# <span class="watchlinkSpan" id="linkTopAct" style="display: ">
# <span class="watchPipe">|</span>
# <span>
# <a class=" " href="http://www.ebay.com/myb/WatchListAdd?_trksid=p2047675.l1359&amp;SubmitAction.AddToListVI=x&amp;item=361417000396&amp;rt=nc&amp;srt=01000100000050424c0bd1eebfef4e6a42a7d5a4d5930a896d1e89f19185836bb3e3cfcaa3f5ac831b2d75c2cb005c5f9637ad52985507eefaff4c5e4bfab573957317fe3d8def258161bb85bcd882af84489eeb18bb34&amp;etn=Watch list&amp;tagId=-99&amp;wt=2aa4b13403d76798fc2c5775ba4cf515&amp;ssPageName=VIP:watchlink:top:en&amp;sourcePage=4340" id="watchLink" rel="nofollow" title="">Add to watch list</a></span>
# </span>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <div style="clear: both;"></div>
# <div class="si-cnt si-cnt-eu vi-grBr vi-padn0 c-std" style="height:100%;">
# <div>
# <div class="si-inner">
# <div class="si-content ">
# <h2 class="si-ttl">
# 							Seller information</h2>
# <div class="bdg-90">
# <div class="mbg vi-VR-margBtm3">
# <a aria-label="Member ID: bestchoiceproducts" href="http://www.ebay.com/usr/bestchoiceproducts?_trksid=p2047675.l2559"> <span class="mbg-nw">bestchoiceproducts</span></a>
# <span class="mbg-l">
# 	            (<a href="http://feedback.ebay.com/ws/eBayISAPI.dll?ViewFeedback&amp;userid=bestchoiceproducts&amp;iid=361417000396&amp;ssPageName=VIP:feedback&amp;ftab=FeedbackAsSeller&amp;rt=nc&amp;_trksid=p2047675.l2560" title="feedback score: 455600">455600</a>
# <span alt="feedback score: 455600" class="vi-mbgds3-bkImg vi-mbgds3-bigStar vi-mbgds3-fb100000-499999" title="feedback score: 455600"></span>)</span>
# </div>
# <div id="si-fb">99.2% Positive feedback</div>
# </div>
# <div class="si-rlDot"></div>
# <div class="si-bdg si-pd-eu">
# <div id="followSeller" style="display:inline;"><div class="fol-widget " data-entity-type="person" id="w1-11">
# <a class="">
# <span>
# <span></span>
# </span>
# <span>Follow this seller</span>
# </a>
# </div>
# </div></div>
# <div id="storeSeller" style="display:inline;"><div class="si-ss-eu">
# <div class="u-flL si-ss-lbl " id="" style="">
# 	Visit store:</div><a alt="Best Choice Products" href="http://stores.ebay.com/Best-Choice-Products?_trksid=p2047675.l2563" title="Best Choice Products"><img alt="" class="si-ss-spr" height="1" src="http://ir.ebaystatic.com/pictures/aw/pics/s.gif" width="1"/> Best Choice Products</a>
# </div>
# </div><div class="si-pd-a" style="overflow: hidden;">
# <a href="http://www.ebay.com/sch/bestchoiceproducts/m.html?item=361417000396&amp;hash=item542621c5cc%3Ag%3An68AAOSwA4dWLp4b&amp;rt=nc&amp;_trksid=p2047675.l2562" id="vi-see-all-lnk">See other items</a>
# <div class="vi-soi-inline-cnt">
# <div id="vi-soi-inline-div" style="display:none;padding-top:10px;">
# <span style="float:left;color:#333;">More...</span>
# <span><a href="#" id="vi-soilayer-alllnk" style="font-size:12px;margin-right:4px;float:right;">See all</a></span>
# <div style="clear:both;"></div>
# <div style="height:auto;">
# <div id="vi-soilayer-inner-cntr" style="margin:5px 0px 10px 0px;height:60px;"></div>
# <div id="vi-soilayer-inner-cntr-none" style="display:none;">bestchoiceproducts has no other items for sale.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div><div id="rtm_html_1527"></div>
# </div>
# <div class="lsp-c lsp-cRight lsp-cL300 lsp-de" id="LeftSummaryPanel">
# <div aria-labelledby="itemInfoLabel" class="is " id="mainContent" role="main" style="overflow:hidden;" tabindex="-1">
# <h2 class="g-hdn" id="itemInfoLabel">Item Information</h2>
# <form action="https://checkout.payments.ebay.com/ws/eBayISAPI.dll?XOProcessor&amp;TransactionId=-1&amp;rsp=true&amp;item=361417000396" method="post" name="viactiondetails">
# <div class="nonActPanel ">
# <div>
# <div class="u-flL lable">
# 		Item condition:</div>
# <div class="u-flL condText " id="vi-itm-cond">New</div>
# </div>
# <!-- offscreen timer widget -->
# <!-- some comment -->
# <!-- volume pricing -->
# <!-- volume pricing ends -->
# <div class="u-cb spcr"></div>
# <div class="">
# <div class="u-flL lable quantity"><label for="qtyTextBox">Quantity:</label></div>
# <div>
# <div class="u-flL qtyCntVal vi-bboxrev-posabs vi-bboxrev-dsplinline">
# <div class="errorIcon" id="w1-14-_errIcon"><!-- err_qty_icon -->
# <img alt="Error icon" class="errorimg" src="http://ir.ebaystatic.com/pictures/aw/pics/s.gif">
# </img></div>
# <input autocomplete="off" class="qtyInput" id="qtyTextBox" name="quantity" size="4" type="text" value="1">
# <span class="qtyTxt vi-bboxrev-dsplblk vi-qty-fixAlignment" style="">
# <span id="qtySubTxt">
# <span class="">
# 						Limited quantity available</span>
# </span>
# <span class="vi-qty-vert-algn vi-qty-slash"> / </span>
# <span class="vi-qtyS-hot-red vi-bboxrev-dsplblk vi-qty-vert-algn vi-qty-pur-lnk">
# <a href="http://offer.ebay.com/ws/eBayISAPI.dll?ViewBidsLogin&amp;item=361417000396&amp;rt=nc&amp;_trksid=p2047675.l2564">491 sold</a></span>
# </span>
# </input></div></div></div></div></form></div></div></div></div></div></div></body></html>
# <div class="u-cb err" id="w1-14-_errMsg"> </div>
# <!-- generating Id's array -->
# <div class="u-dspn">
# <b id="w1-14_qtyErr_0">Please enter a quantity of $qty_dummy$ or less</b>
# <b id="w1-14_qtyErr_1">Please enter a quantity of 1</b>
# <b id="w1-14_qtyErr_2">Purchases are limited to $qty_dummy$ per buyer</b>
# <b id="w1-14_qtyErr_3">Please enter quantity of 1 or more</b>
# <b id="w1-14_qtyErr_4">Please enter a lower number</b>
# <b id="w1-14_qtyErr_5">Choose quantity that is less than $qty_dummy1$ or equal to $qty_dummy$</b>
# <b id="w1-14_qtyErr_6">You can only choose quantity that is equal to $qty_dummy$</b>
# </div>
#
#
# <div class="u-cb spcr"></div>
#
#
# <div class="c-std vi-ds3cont-box-marpad">
# <div class="actPanel vi-noborder ">
# <!-- //TODO : remove hardcoded ID for Shipping cost -->
# <div id="vi-orgPrc-container" style=" display:block; ">
# <div class="u-cb spcr vi-VR-prcTmt-hide"></div>
# <div class="u-cb vi-VR-prcTmt-hide">
# <div class="vi-bbox-dspn u-flL lable" id="orgPrc-lbl" style="">
# 	List price:</div><span class="notranslate ms-orp" id="orgPrc">
# 						$224.95</span>
# <a href="javascript:;" id="e1"><img alt="What does this price mean?" class="ms-hlp" src="http://ir.ebaystatic.com/pictures/aw/pics/icons/iconBubbleHelp.gif"/></a>
# <div class="oly_upnl" id="w1-16-overlay"><div class="ms-olp">
# <div class="ms-olp-ttl">What does this price mean?</div>
# <div class="ms-olp-cnt">This is the price (excluding shipping and handling fees) a seller has provided at which the same item, or one that is nearly identical to it, is being offered for sale or has been offered for sale in the recent past. The price may be the seller's own price elsewhere or another seller's price. The "off" amount and percentage simply signifies the calculated difference between the seller-provided price for the item elsewhere and the seller's price on eBay. If you have any questions related to the pricing and/or discount offered in a particular listing, please contact the seller for that listing.</div>
# </div>
# </div>
# </div>
# </div>
# <div id="vi-youSaveSTP-container" style=" display:block; ">
# <div class="u-cb spcr vi-VR-prcTmt-hide"></div>
# <div class="u-cb ms-as-rw vi-VR-prcTmt-hide">
# <div class="u-flL lable" id="youSaveSTP-lbl" style="">
# 	You save:</div><span class="notranslate ms-as" id="youSaveSTP">
# 					$125.00 (55% off)</span>
# </div>
# </div>
# <div class="u-cb spcr vi-bbox-spcr15 "></div>
# <div class="u-cb">
# <div class="vi-bbox-dspn u-flL lable binLable" id="prcIsum-lbl">Now:</div>
# <div class="u-flL w29 vi-price" id="vi-mskumap-none" itemprop="offers" itemscope="itemscope" itemtype="http://schema.org/Offer" style="">
# <span class="notranslate" id="prcIsum" itemprop="price" style="">US $99.95</span>
# <div class="sh-CostBB" id="isum-shipCostDiv"></div>
# <span content="http://schema.org/InStock" itemprop="availability"></span>
# <span content="USD" itemprop="priceCurrency"></span>
# <!--Added for VAT message - DE site. Show VAT included msg just below the price. Converted price message should come after this message.-->
# <!-- Vat Excluded message -->
# </div>
# <!-- inserting code for another button -->
# <!-- code ends  -->
# <div class="u-flL">
# <span id="binBtn_btn_parent">
# <input _sp="p2047675.l1356" class="btn btn-prim btn-m vi-VR-btnWdth-L" id="binBtn_btn" onclick="javascript:return false;" style="" type="submit" value="Buy It Now"/>
# </span>
# </div>
# </div>
# <div class="u-cb spcr vi-bbox-spcr10"></div>
# <div class="u-cb ">
# <div class="vi-bbox-dspn u-flL lable"> </div>
# <div class="vi-bbox-dspn u-flL w29"> </div>
# <span>
# <span id="isCartBtn_btn_parent">
# <a _sp="p2047675.l1473" class="btn btn-scnd btn-m vi-VR-btnWdth-L" href="http://cart.payments.ebay.com/sc/add?item=iid:361417000396,qty:1&amp;ssPageName=CART:ATC" id="isCartBtn_btn" rel="nofollow" role="button" style="">
# 									Add to cart</a>
# </span>
# </span>
# </div>
# <div class="u-cb spcr"></div>
# </div>
# <div class="watchListCmp vi-noborder ">
# <div class="vi-bbox-dspn u-flL lable"> </div>
# <span class="u-flL w29 ap-numWatcher ap-watchCount" id="vi-bybox-watchers-container">
# <span id="vi-bybox-watchers" style="padding-right: 10px;">
# <span class="vi-buybox-watchcount">912</span> watching</span>
# </span>
# <div class=" u-flL ">
# <div class="vi-atw-btm-lnk " id="vi-atl-lnk" style="">
# <a href="http://www.ebay.com/myb/WatchListAdd?_trksid=p2047675.l1360&amp;SubmitAction.AddToListVI=x&amp;item=361417000396&amp;rt=nc&amp;srt=0100010000005080f096f38d3b0637741b9c1b55e5cdbee09fd6ab554a9d7df65c3b776fd1fdfc75b2c8ab5e61f440805f080f1b540908a363677d7930f70a7e8329382a532bca5b07d6141e1140701f20de0152b445c1&amp;wt=2aa4b13403d76798fc2c5775ba4cf515&amp;ssPageName=VIP:watchlink:top:en&amp;sourcePage=4340" i="-99" n="Watch list">
# <span class="vi-atw-icn"></span>
# <span class="vi-atw-txt">Add to watch list</span>
# <span class="vi-rmw-txt">Remove from watch list</span>
# </a>
# </div>
# <div class="vi-atw-btm-lnk " id="vi-atw-full" style="display:none;">
# <span class="vi-atw-full-lnk">
# <span class="vi-atw-icn"></span><span class="vi-atw-txt">Watch list is full</span>
# </span>
# </div>
# <div class="vi-bbox-dspn u-cb spcr "></div>
# <div class="clnw clnw-lk fx-clnw " id="vi-col-abf-lnk">
# <span data-c="Save, organize and share what you love by adding this to a collection." data-cd="You already added this item to a collection, but you can add it to other ones." id="clnw-txt"></span>
# <a class="clnw-collect clnw-c clnw-str" data-id="361417000396" data-var="" href="#"><span></span>
# <span class="clwn-main-txt">Add to collection</span>
# </a>
# </div>
# </div>
# <div class="vi-bbox-dspn u-cb spcr"></div>
# </div><div id="why2buy"><div class="w2b w2bsls">
# <div class="w2b-cnt w2b-3 w2b-red"><span class="w2b-sgl">491 sold</span></div>
# <div class="w2b-cnt w2b-3 w2b-brdr"><span class="w2b-sgl">15 inquiries</span></div>
# <div class="w2b-cnt w2b-3 w2b-brdr"><span class="w2b-sgl">Experienced seller</span></div>
# </div>
# </div></div>
# <div id="vi-lkhdr-v4-plchdr"></div>
# <div id="vi-spw-atf">
# </div>
# <div id="shippingSummary"><div class="u-cb spcr"></div>
# <div class="u-cb spcr"></div>
# <div>
# <div class="u-flL lable" id="shippingPlaceHolderId">Shipping:</div>
# <div class="u-flL sh-col">
# <span id="shSummary">
# <span class="notranslate sh-fr-cst " id="fshippingCost">
# <span>FREE</span>
# </span>
# <span id="fShippingSvc">
# 				Standard Shipping<!-- GSP -->
# </span>
# <span> | </span>
# <span>
# <a aria-describedby="shippingPlaceHolderId" class="vi-ds3-ter-a si-pd sh-nwr" href="#shpCntId" id="e3"> See details </a>
# </span>
# <script type="text/javascript">
# 		function getElementsByClassName(e,t){var n=[];var r=new RegExp("(^| )"+t+"( |$)");var i=e.getElementsByTagName("*");for(var s=0,o=i.length;s<o;s++)if(r.test(i[s].className))n.push(i[s]);return n}
# 	</script>
# <script type="text/javascript">
# 				var shElemntArry = getElementsByClassName(document.body,'sh-CostBB'); for(var i = shElemntArry.length - 1; i >= 0; --i){shElemntArry[i].style.display = 'none';shElemntArry[i].innerHTML = "Free shipping";}
# 				var shElemntArry = getElementsByClassName(document.body,'sh-CostBB-lkdhdr'); for(var i = shElemntArry.length - 1; i >= 0; --i){shElemntArry[i].style.display = 'inline';shElemntArry[i].innerHTML = "Free shipping";}
# 			</script>
# <script type="text/javascript">
# 					var convP = document.getElementById('convbinPrice'); if(convP){var x = convP.getElementsByTagName("SPAN")[0]; if(x){x.style.display = 'none';};};
# 				</script>
# <div id="sh-not-mayBe" style="display:none"></div>
# </span>
# <!-- Build Estimated delivery and CBT message -->
# </div>
# <div class="clear"></div>
# </div></div><div id="itemLocation"><div class="lable u-flL vi-acc-hide"> </div>
# <div class="u-flL iti-w75 ">
# <div class="iti-eu-txt iti-spacing">
# <div class="iti-eu-label vi-u-flL" id="" style="">
# 	Item location:</div><div class="iti-eu-bld-gry ">Rancho Cucamonga, California, United States</div>
# <div class="clear"></div>
# </div>
# </div>
# <div class="u-cb"></div>
# </div><div class="u-cb"></div>
# <div id="shipsTo"><div class="lable u-flL vi-acc-hide"> </div>
# <div class="u-flL iti-w75">
# <div id="shipsToSummary">
# <div class="iti-eu-txt iti-spacing">
# <div class="iti-eu-label vi-u-flL" id="vi-acc-shpsToLbl">Ships to: </div>
# <div class="iti-eu-bld-gry vi-shp-pdg-rt" id="vi-acc-shpsToLbl-cnt">
# 			United States<span class="sh-nwr" style="font-weight: normal;padding-left:5px;">
# <span class="hideForAcc"> | </span>
# <a class="vi-ds3-ter-a" href="#shpCntId" id="e5">See exclusions</a>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div><div id="deliverySummary"><div class="u-cb spcr"></div>
# <div id="impchSummary" style="display: none;">
# <div class="u-flL lable">Import charges:</div>
# <div class="u-flL sh-col">
# <div>
# <span id="impch_show" style="display: none;">
# <span class="sh-impchCost" id="impchCost"></span>
# 				 (amount confirmed at checkout) </span>
# <span id="impch_xo" style="">To be provided at checkout </span>
# <span class="sh-bubble">
# <a class="sh-qmark" href="javascript:;" id="imprthlp"> <b class="g-hdn">help icon for Shipping - opens a layer</b></a>
# </span>
# <div class="oly_upnl" id="imprtoly"><div aria-live="assertive" class="vi-shp-shpolay" role="alert">
# <span id="vi-sh-imp-nonEU" style="">This amount includes applicable customs duties, taxes, brokerage and other fees. This amount is subject to change until you make payment. For additional information, see the Global Shipping Program <a href="http://pages.ebay.com/shipping/globalshipping/buyer-tnc.html#programfees" target="_blank">terms and conditions<b class="hideforacc">- opens in a new window or tab</b></a></span>
# <span id="vi-sh-imp-EU" style="display:none">This amount includes applicable customs duties, taxes, brokerage and other fees. This amount is subject to change until you make payment. If you reside in an EU member state besides UK, import VAT on this purchase is not recoverable. For additional information, see the Global Shipping Program <a href="http://pages.ebay.com/shipping/globalshipping/buyer-tnc.html#programfees" target="_blank">terms and conditions<b class="hideforacc">- opens in a new window or tab</b></a></span>
# </div>
# </div>
# </div>
# <div>No additional import charges on delivery</div>
# </div>
# <div class="u-cb spcr"></div>
# </div><div class="u-flL lable">Delivery:</div>
# <div class="u-flL sh-col">
# <span id="delSummary">
# <!-- Fi rst shipping service's cost -->
# <!-- PC 5555 cases -->
# <div class="sh-del-frst " role="alert">
#
# Estimated between <span class="vi-acc-del-range"><b>Wed. Nov. 18 and Wed. Nov. 25</b></span><span class="">
# <a class="sh-qmark" href="javascript:;" id="hldhlp"> <b class="g-hdn">help icon for Estimated delivery date - opens a layer</b></a>
# </span>
# <div class="oly_upnl" id="w1-22-overlay"><div aria-live="assertive" class="vi-shp-shpolay" role="alert">
# <a href="http://pages.ebay.com/help/buy/contextual/estimated-delivery.html" target="_blank">Estimated delivery dates <b class="hideforacc"> - opens in a new window or tab</b></a> include seller's handling time, origin ZIP Code, destination ZIP Code and time of acceptance and will depend on shipping service selected and receipt of <a href="http://pages.ebay.com/help/buy/contextual/domestic-handling-time.html" target="_blank">cleared payment<b class="hideforacc"> - opens in a new window or tab</b></a>. Delivery times may vary, especially during peak periods.</div>
# </div>
# </div>
# ...
#
# 			var notification = raptor.require("com.ebay.raptor.vi.notification");
# 			new notification({type:0, startTime:1000, displayTime:7000, notificationElm:'vi_notification_new', cmpWidth:240, leftPaddingOffset:10,alignType:0, redesign:false, ph1varA:true});
#
# 						$("#e1").click(function(){
# 							trackingUtil("VI_STP_COMPARE_HELP_ICON");
# 						});
#
# var addToCollect = raptor.require("com.ebay.raptor.vi.addtocollectionr1");
# new addToCollect({js:"http://ir.ebaystatic.com/rs/c/collect-widget-init-v1-042915.js", pageId:"2047675", clsName:"clnw-collect", csrfToken:"01000100000050bdbba39411ba45ea70ac11fe9810c32ca7c8b1a567b24fbcc4c86e644519f7f57ba5e4afce5544954b281ebef6a037c4d278e693cb959e748988051fbbec591a351f8cdb12b0d5c333d9e6ed84a13d73", varElmId:"var", isProdEnv:true, itmclcnt:0, cvarmap:null, siteid:"EBAY-US", countryid:"US", localeid:"en-US"});
# $("#e3").click(function(){var tabId = ($("body.vi-deeplinksv2").length > 0) ? "viTabs_0" : "viTabs_1";trackingUtil("Shipping_See_all_details_ItemSummary");try{$("#" + tabId)[0].trigger('click', ['noTabTracking']);}catch(e){$("#" + tabId).trigger('click', ['noTabTracking']);}});$("#expedited_link").click(function(){var tabId = ($("body.vi-deeplinksv2").length > 0) ? "viTabs_0" : "viTabs_1";trackingUtil("OneDayShipping_Link_in_Delivery_Expedited_Shipping");try{$("#" + tabId)[0].trigger('click', ['noTabTracking']);}catch(e){$("#" + tabId).trigger('click', ['noTabTracking']);}});$("#e4").click(function(){var tabId = ($("body.vi-deeplinksv2").length > 0) ? "viTabs_0" : "viTabs_1";trackingUtil("Calculate_link_ItemSummary");try{$("#" + tabId)[0].trigger('click', ['noTabTracking']);}catch(e){$("#" + tabId).trigger('click', ['noTabTracking']);}});var tabId = ($("body.vi-deeplinksv2").length > 0) ? "viTabs_0" : "viTabs_1";$("#e5").click(function(){try{$("#" + tabId)[0].trigger('click', ['noTabTracking']);}catch(e){$("#" + tabId).trigger('click', ['noTabTracking']);}trackingUtil("See_exclusions_itemInfo");});
#
#
# 	$("#e6").click(function(){
# 		var tabId = ($("body.vi-deeplinksv2").length > 0) ? "viTabs_0" : "viTabs_1";
# 		try{
# 		$("#" + tabId)[0].trigger('click', ['noTabTracking']);
# 		}catch(e){
# 			$("#" + tabId).trigger('click', ['noTabTracking']);
# 		}
# 		trackingUtil("Payments_See_details_Iteminfo");
# 	});
#
# 	$(".vi-ppc-offlnk").click(function(){
# 		trackingUtil("VIP_PPC_OFFER_LNK");
# 	});
#
# 	$("#e7").click(function(){
# 		var tabId = (false) ? "viTabs_0" : "viTabs_1";
# 			if (!(false)){
# 				tabId = ($("body.vi-deeplinksv2").length > 0) ? "viTabs_0" : "viTabs_1";
# 			}
#
# 		try{
# 		$("#" + tabId)[0].trigger('click', ['noTabTracking']);
# 		}catch(e){
# 			$("#" + tabId).trigger('click', ['noTabTracking']);
# 		}
# 		trackingUtil("Returns_Read_details");
# 	});
#
# 	$("#vi-VR-return-deLnk").click(function(){
# 		var tabId = (false) ? "viTabs_0" : "viTabs_1";
# 			if (!(false)){
# 				tabId = ($("body.vi-deeplinksv2").length > 0) ? "viTabs_0" : "viTabs_1";
# 			}
#
# 		try{
# 		$("#" + tabId)[0].trigger('click', ['noTabTracking']);
# 		}catch(e){
# 			$("#" + tabId).trigger('click', ['noTabTracking']);
# 		}
# 		trackingUtil("Returns_Read_details");
# 	});
# $("#").click(function(){$("#viTabs_0")[0].click();});
# 	raptor.require("com.ebay.raptor.vi.SMEUtil").init({isShowRedesignBanner:false});
#
# 	var ia = raptor.require('com.ebay.raptor.vi.ItemAttributes');
# 	<!-- TODO: remove hardcoded ID -->
# 	new ia({readMoreId : 'readFull', hiddenContentId : 'hiddenContent'});
#
# 	var deeplinksv2 = false;
# 	var isAutoCars = false;
# 	var prForBotsEnabled = false;
# 	var enableSpaceBarOnTabsFlag = false;
#     $("#viTabs_0").bind('click', function(event, param) {
#         if(param !== 'noTabTracking') {
#             trackingUtil("Description_Tab");
#         }
#     });
#
#     $('ul.nav-tabs-m a').bind("keydown",function(event){
# 	    if(event.keyCode==37){
# 				//check if any element exists to the left
# 				var previousTab = $(this).parent().prev('li');
# 				var previousChildLink = previousTab.children("a");
# 				if(previousTab.length>0){
# 					previousChildLink.trigger("click");
# 					previousChildLink.focus();
# 				}else{
# 				}
# 	    }
# 	    else if(event.keyCode==39){
# 	    		//check if any element exists to the right
# 	    		var nextTab=$(this).parent().next('li');
# 	    		var nextChildLink = nextTab.children("a");
# 	    		if(nextTab.length>0){
# 					nextChildLink.trigger("click");
# 					nextChildLink.focus();
# 				}else{
# 				}
# 	    }
# 	    else if(enableSpaceBarOnTabsFlag && event.keyCode==32){
# 	    	var focussedElement = $(this);
# 	    	focussedElement.trigger("click");
# 	    }
#     });
#
#     if(enableSpaceBarOnTabsFlag){
#     	window.onkeydown = function(e) {
# 			  if($('ul.nav-tabs-m a').is(':focus'))return !(e.keyCode == 32);
# 			};
#     }
#
# 	$('ul.nav-tabs-m a').click(function (event) {
# 		event.stopPropagation();
# 		var id = $(this).parent().index();
# 		var tempAttr;
# 		id+=1;
# 		if ($(this).parent().attr("class") != "item active sel" ) {
# 			$('ul.nav-tabs-m li').each(function(index) {
# 			     $(this).removeClass("active sel");
# 			     $(this).children("a").attr("aria-selected","false");
# 			     $("#selectedSpan").remove();
# 			});
#
# 			$('div.tab-content-m div').each(function(index) {
# 			     $(this).removeClass("active sel");
# 			});
# 			$("ul.nav-tabs-m li:nth-child("+id+")").addClass("active sel");
# 			$("ul.nav-tabs-m li:nth-child("+id+")").children("a").attr("aria-selected","true");
# 			$("ul.nav-tabs-m li:nth-child("+id+")").children("a").append("<span id='selectedSpan' class='gh-ar-hdn'> current</span>");
# 			$("div.tab-content-m div:nth-child("+id+")").addClass("active sel");
#
#
#
# 			if ((id == 1) && (deeplinksv2)) {
# 				var tabNum = 2;
# 				if (isAutoCars) {
# 					tabNum = 3;
# 				}
# 				$("div.tab-content-m div:nth-child(" + tabNum + ")").addClass("active sel");
# 				$(".vi-readMore-ship").addClass("u-dspn");
# 			}
# 			if ((id == 2) && (deeplinksv2)) {
# 				$(".vi-readMore-ship").removeClass("u-dspn");
# 			}
#
# 		}
# 	});
#
# 	if (deeplinksv2){
# 		$(document).ready(function(){
# 			$('a[href^="#"].vi-ds3-ter-a').on('click',function (e) {
# 			    e.preventDefault();
# 			    var target = this.hash,
# 			    $target = $(target);
# 			    $('html, body').stop().animate({
# 			        'scrollTop': $target.offset().top
# 			    }, 700, 'swing', function () {
# 			        window.location.hash = target;
# 			    });
# 			});
# 		});
# 	}
#
# 	$("#viTabs_1").bind('click', function(event, param) {
# 		if(param !== 'noTabTracking') {
# 		       if(event.target.innerHTML == "Vehicle History Report"){
#                  trackingUtil("VEHICLE_HISTORY_REPORT_TAB_CLICK");
#                 }
# 		  else {
# 			      trackingUtil("Shipping_and_Payments_Tab");
# 	           }
#
# 		}else{
# 			if(navigator && navigator.userAgent && navigator.userAgent.indexOf("Opera") != -1) {
# 				setTimeout(function(){document.location.hash = document.location.hash.substring(1);},50);
# 			}
# 		}
# 	});
#
# 	$("#viTabs_2").bind("click",function(event,param){
# 	   trackingUtil("VEHICLE_SHIPPINGPAYMENT_TAB");
# 	});
# 	if(prForBotsEnabled){
# 		$(document).ready(function(){
# 			 trackingUtil("VI_DOCUMENT_READY_TRIGGER");
# 		});
# 	}
#
# 	$(".rpMainCont a").attr('target','_blank');
#
# 	var tRtmPubsub = raptor.require('pubsub');
# 	if(tRtmPubsub) {
# 		tRtmPubsub.subscribe("ADD_TO_WATCH_TRIGGERED", function(msg){ $('body').trigger(("RTM_PUBLISH"),{'pids':(["280"])});});
# 	}
#
# 	var tRtmPubsub = raptor.require('pubsub');
# 	if(tRtmPubsub) {
# 		tRtmPubsub.subscribe("_SUBMIT_CARTBTN", function(msg){ $('body').trigger(("RTM_PUBLISH"),{'pids':(["20047"])});});
# 	}
#
# 	$("#_rtop").click(function(){
# 		trackingUtil("Return_to_top");
# 	});
# raptor.require('com.ebay.raptor.vi.cookie.ScreenDetail').init({"cookieName" : "dp1","cookieletName" : "pbf","currentResValue" : {"maxWidth":-1,"minWidth":-1,"name":"DEFAULT","value":0,"id":0,"integer":0},"resRange" : [{"maxWidth":-1,"minWidth":-1,"name":"DEFAULT","value":0,"id":0,"integer":0},{"maxWidth":1024,"minWidth":0,"name":"RES_1024","value":1,"id":1,"integer":1},{"maxWidth":1152,"minWidth":1025,"name":"RES_1152","value":2,"id":2,"integer":2},{"maxWidth":1280,"minWidth":1153,"name":"RES_1280","value":3,"id":3,"integer":3},{"maxWidth":1366,"minWidth":1281,"name":"RES_1366","value":4,"id":4,"integer":4},{"maxWidth":1440,"minWidth":1367,"name":"RES_1440","value":5,"id":5,"integer":5},{"maxWidth":1680,"minWidth":1441,"name":"RES_1680","value":6,"id":6,"integer":6},{"maxWidth":2147483647,"minWidth":1681,"name":"RES_MAX","value":7,"id":7,"integer":7}],"resBits" : [85,86,87],"currentViewportValue" : {"maxWidth":-1,"minWidth":-1,"name":"DEFAULT","value":0,"id":0,"integer":0},"viewportRange" : [{"maxWidth":-1,"minWidth":-1,"name":"DEFAULT","value":0,"id":0,"integer":0},{"maxWidth":1020,"minWidth":0,"name":"VIEWPORT_1","value":1,"id":1,"integer":1},{"maxWidth":1024,"minWidth":1021,"name":"VIEWPORT_2","value":2,"id":2,"integer":2},{"maxWidth":1148,"minWidth":1025,"name":"VIEWPORT_3","value":3,"id":3,"integer":3},{"maxWidth":1152,"minWidth":1149,"name":"VIEWPORT_4","value":4,"id":4,"integer":4},{"maxWidth":1276,"minWidth":1153,"name":"VIEWPORT_5","value":5,"id":5,"integer":5},{"maxWidth":1280,"minWidth":1277,"name":"VIEWPORT_6","value":6,"id":6,"integer":6},{"maxWidth":2147483647,"minWidth":1281,"name":"VIEWPORT_7","value":7,"id":7,"integer":7}],"viewportBits" : [69,70,71]});
# 	raptor.require('com.ebay.raptor.vi.tracking.SitespeedTimers').init({"itemId" : "361417000396"});
# $rwidgets(['com.ebay.raptor.vi.isum.smartBackTo','w1-1',{"smtBackToAnchorArrowId":"smtBackToAnchorArrow","smtBackToAnchorId":"smtBackToAnchor","numLevels":1,"isBacktoSearch":false},0,0,0,['ui.InlineFeedbackLink','w1-2']],['com.ebay.raptor.vi.overlayHandler','w1-3'],['com.ebay.raptor.vi.topmessagepanel.TopMessagePanel','w1-4',{"CHINESE_BUYER_HIGH_BIDDER_PC_ON":"You're the highest bidder. ","CHINESE_BUYER_HIGH_BIDDER_RESERVE_NOT_MET_PC_ON":"You're the highest bidder but the reserve price has not been met. ","CHINESE_BUYER_OUTBIDDER_PC_ON":"You've been outbid. ","smId":"w1-4-_msg","dummy":"##n##","inlineExp":false,"autoRefreshSvcId":"AUTO_REFRESH_SVC","panelId":"msgPanel"}],['ebay.viewItem.PicturePanel','w1-5',{"id":"vi_pic_panel","isEnableTouch":false,"mainImgId":"icImg","mainImgHldr":"mainImgHldr","thbrImgId":"icThrImg","prLdImgThrsld":5,"fsImgList":[{"thumbImgUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002Fn68AAOSwA4dWLp4b\u002Fs-l64.jpg","thumbImgSize":null,"displayImgUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002Fn68AAOSwA4dWLp4b\u002Fs-l300.jpg","displayImgSize":null,"maxImageUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002Fn68AAOSwA4dWLp4b\u002Fs-l1600.jpg","maxImageHeight":1600,"maxImageWidth":1600,"zoomEnabled":true,"enlargeEnabled":true},{"thumbImgUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002F7HMAAOSwT4lWRoQX\u002Fs-l64.jpg","thumbImgSize":null,"displayImgUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002F7HMAAOSwT4lWRoQX\u002Fs-l300.jpg","displayImgSize":null,"maxImageUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002F7HMAAOSwT4lWRoQX\u002Fs-l1600.jpg","maxImageHeight":1600,"maxImageWidth":1600,"zoomEnabled":true,"enlargeEnabled":true},{"thumbImgUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002FxtcAAOSwlV9WRoQX\u002Fs-l64.jpg","thumbImgSize":null,"displayImgUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002FxtcAAOSwlV9WRoQX\u002Fs-l300.jpg","displayImgSize":null,"maxImageUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002FxtcAAOSwlV9WRoQX\u002Fs-l1600.jpg","maxImageHeight":1600,"maxImageWidth":1600,"zoomEnabled":true,"enlargeEnabled":true},{"thumbImgUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002FNcoAAOSwiwVWRoQa\u002Fs-l64.jpg","thumbImgSize":null,"displayImgUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002FNcoAAOSwiwVWRoQa\u002Fs-l300.jpg","displayImgSize":null,"maxImageUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002FNcoAAOSwiwVWRoQa\u002Fs-l1600.jpg","maxImageHeight":1600,"maxImageWidth":1600,"zoomEnabled":true,"enlargeEnabled":true},{"thumbImgUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002FPisAAOSwMTZWRoQY\u002Fs-l64.jpg","thumbImgSize":null,"displayImgUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002FPisAAOSwMTZWRoQY\u002Fs-l300.jpg","displayImgSize":null,"maxImageUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002FPisAAOSwMTZWRoQY\u002Fs-l1600.jpg","maxImageHeight":1600,"maxImageWidth":1600,"zoomEnabled":true,"enlargeEnabled":true},{"thumbImgUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002F7IwAAOSwT4lWRoQY\u002Fs-l64.jpg","thumbImgSize":null,"displayImgUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002F7IwAAOSwT4lWRoQY\u002Fs-l300.jpg","displayImgSize":null,"maxImageUrl":"http:\u002F\u002Fi.ebayimg.com\u002Fimages\u002Fg\u002F7IwAAOSwT4lWRoQY\u002Fs-l1600.jpg","maxImageHeight":1600,"maxImageWidth":1600,"zoomEnabled":true,"enlargeEnabled":true}],"isSelfHosted":true,"fsId":"vi_main_img_fs","mskuId":"sel-msku-variation"},0,0,0,['ebay.viewItem.ZoomEnlarge','w1-6',{"id":"vi_pic_zoomEnlarge","mainImgId":"icImg","zoomEnMsgId":"zoom_enlarge_msg","zoomMsg":"Mouse over image to zoom","enlargeMsg":"Click to view larger image and other views","zoomEnMsgCntId":"zoom_enlarge_msg_cnt"},'w1-5','vi_pic_zoomEnlarge',0,['ebay.viewItem.Zoom','w1-7',{"id":"vi_pic_zoom","mainImgId":"icImg","maskId":"zoom_img_mask","zoomSelId":"zoom_selector", ...
# 			</script><!-- Adding merch content js -->
# </div><!-- RcmdId _vi_index-jsp,RlogId t6ulcpjqcj9%3Feog4d72f%2B1%3A35-15112c9cf16-0x167 -->

# %%
#for item in tree_soup.find_all('desc_div'):
#    print item
    
tree_soup.select(".desc_div")
# Out:
# []

# %%
tree_soup.find("div", {"id": "desc_div"})
# Out:
# <div class="" id="desc_div">
# <script>if ((typeof (oGaugeInfo) != "undefined")){var descGaugeStartInfo = {descST:(new Date()).getTime()};}</script>
# <iframe class="" frameborder="0" height="10000" id="desc_ifr" marginheight="0" marginwidth="0" src="http://vi.vipr.ebaydesc.com/ws/eBayISAPI.dll?ViewItemDescV4&amp;item=361417000396&amp;t=1447268056000&amp;tid=10&amp;category=117414&amp;seller=bestchoiceproducts&amp;excSoj=1&amp;excTrk=1&amp;lsite=0&amp;ittenable=false&amp;domain=ebay.com&amp;descgauge=1" title="Seller's description of item" width="99%"></iframe>
# </div>

# %% [markdown]
# ## Part 3: Using a Web API to get meta data

# %% [markdown]
# We do not always have to web scrape. Sometimes the web site provides an API to access the information. The API
# is usually easier to use then constructing your own CSS selector. In the following exercise we will be using the NYT [API](http://developer.nytimes.com/docs/read/article_search_api_v2) to programmatically retrieve its articles.
#
# 1. Obtain an API key from the NYT for the Article Search API:
#    [http://developer.nytimes.com/apps/register](http://developer.nytimes.com/apps/register)
#
# 2. Now that we have access we can begin to have some fun!  Make a request to the article search API endpoint to
#    retrieve the articles for last week.
#     * Look for what [parameters](http://developer.nytimes.com/docs/read/article_search_api_v2) you can set in your request using the API
#     * Use [Requests](http://docs.python-requests.org/en/latest/) to interact with the API.
#
#     ```python
#     def single_query(link, payload):
#         response = requests.get(link, params=payload)
#         if response.status_code != 200:
#             print 'WARNING', response.status_code
#         else:
#             return response.json()
#
#     if __name__ == '__main__':
#         link = 'http://api.nytimes.com/svc/search/v2/articlesearch.json'
#         payload = {'api-key': '74c73309c1052e6aa1785df7cd5cef8c:9:69947183'}
#         html_str = single_query(link, payload)
#     ```
#
# 3. Examine one of the articles returned.  Look at it's structure and the fields returned.  Make sure you can get a single article (and you know what it looks like) before you retrieve __ALL__ of the NYT.
#
# 4. Now that you have some experience with the API and can successfully access articles with associated metadata, it
#    is time to start storing them in [MongoDB](http://www.mongodb.org/)!
#
# 5. Now that you have a sense of what a single article response looks like, we can begin to scale up.  Begin
#    downloading all of the NYT articles starting with the most recent.  You will not have time (or effort) to
#    download all of the corpus, so let us start with the most recent articles and download as many as we can!  Store
#    these in mongoDB.
#
# 6.  Inspect how many articles were returned from your request for all of the NYT.
#     * How many documents are there?
#     * How many total articles are there in all of the NYT?
#     * Look to the API docs for the Article Search API to learn about why there is a discrepancy between these two         numbers (and how to find the second number -- total articles)
#
# 7. The NYT does some things to prevent us from getting it's articles.  But we are clever data scientists (cleverer     than the NYT API that is)!
#     * Find out how to circumvent the API pagination.
#     * The NYT is rate limited.  Deal with it.
#     * The API only lets you access a fixed number of pages (from the pagination).  What is this number and how can
#       you get around this limit?
#
# 8. Once you have figured how to deal with the NYT quirks, we are ready to start looping.  Begin to download the
#    10,000 most recent NYT articles.
#
#     * You will want to check how your loop is progressing, be sure to print some checkpoint information on how many
#       documents it has downloaded (maybe every 100 articles?).

# %%
import numpy as np
import pandas as pd
import itertools

# %%
import pymongo
from pymongo import MongoClient
import json
import pprint
from bson import json_util
import re

# %%
def single_query(link, payload):
    response = requests.get(link, params=payload)
    if response.status_code != 200:
        print 'WARNING', response.status_code
    else:
        return response.json()

# %%
html_str.keys()
# Out:
# [u'status', u'response', u'copyright']

# %%
pp = pprint.PrettyPrinter(4, depth=4)
pp.pprint(html_str['response']['docs'])
# Out:
# [   {   u'_id': u'5645c5bd7988106302182d3a',
#         u'abstract': None,
#         u'blog': [],
#         u'byline': [],
#         u'document_type': u'multimedia',
#         u'headline': {   u'main': u'Your Friday Briefing'},
#         u'keywords': [],
#         u'lead_paragraph': u'Here\u2019s what you need to know to start your day',
#         u'multimedia': [   {   u'height': 126,
#                                u'legacy': {...},
#                                u'subtype': u'wide',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/13/nytnow/13nytnow-jihadifader/13nytnow-jihadifader-thumbWide.jpg',
#                                u'width': 190},
#                            {   u'height': 411,
#                                u'legacy': {...},
#                                u'subtype': u'xlarge',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/13/nytnow/13nytnow-jihadifader/13nytnow-jihadifader-articleLarge.jpg',
#                                u'width': 600},
#                            {   u'height': 75,
#                                u'legacy': {...},
#                                u'subtype': u'thumbnail',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/13/nytnow/13nytnow-jihadifader/13nytnow-jihadifader-thumbStandard.jpg',
#                                u'width': 75}],
#         u'news_desk': u'NYT Now',
#         u'print_page': None,
#         u'pub_date': u'2015-12-13T00:00:00Z',
#         u'section_name': u'NYT Now',
#         u'slideshow_credits': u'via AP',
#         u'snippet': u'Here\u2019s what you need to know to start your day',
#         u'source': u'The New York Times',
#         u'subsection_name': None,
#         u'type_of_material': u'Slideshow',
#         u'web_url': u'http://www.nytimes.com/slideshow/2015/12/13/nytnow/your-friday-briefing.html',
#         u'word_count': u'10'},
#     {   u'_id': u'563bb8507988103d373bcd4e',
#         u'abstract': None,
#         u'blog': [],
#         u'byline': [],
#         u'document_type': u'article',
#         u'headline': {   u'content_kicker': u'Market Report',
#                          u'main': u'Not Your Grandpa\u2019s Sweater Vests'},
#         u'keywords': [   {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'1',
#                              u'value': u'Knitting and Knit Goods'}],
#         u'lead_paragraph': u'In playful patterns and schoolboy silhouettes, this season\u2019s styles riff on the classic knit.',
#         u'multimedia': [],
#         u'news_desk': u'TStyle',
#         u'print_page': None,
#         u'pub_date': u'2015-12-03T00:00:00Z',
#         u'section_name': u'T Magazine',
#         u'slideshow_credits': None,
#         u'snippet': u'In playful patterns and schoolboy silhouettes, this season\u2019s styles riff on the classic knit.',
#         u'source': u'The New York Times',
#         u'subsection_name': None,
#         u'type_of_material': u'News',
#         u'web_url': u'http://www.nytimes.com/2015/12/03/t-magazine/sweater-vests-market-report.html',
#         u'word_count': u'14'},
#     {   u'_id': u'563759d8798810408f2996b6',
#         u'abstract': None,
#         u'blog': [],
#         u'byline': {   u'original': u'By JEN CHANEY', u'person': [{...}]},
#         u'document_type': u'article',
#         u'headline': {   u'content_kicker': u'The Leftovers',
#                          u'main': u'\u2018The Leftovers\u2019 Season 2, Episode 5: Laughing With God'},
#         u'keywords': [   {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'1',
#                              u'value': u'Television'},
#                          {   u'is_major': u'N',
#                              u'name': u'creative_works',
#                              u'rank': u'2',
#                              u'value': u'The Leftovers (TV Program)'}],
#         u'lead_paragraph': u'Sunday\u2019s episode focused on the seemingly boundless bad luck that befalls Matt Jamison.',
#         u'multimedia': [   {   u'height': 126,
#                                u'legacy': {...},
#                                u'subtype': u'wide',
#                                u'type': u'image',
#                                u'url': u'images/2015/10/29/arts/29TVRECAP1/29TVRECAP1-thumbWide-v2.jpg',
#                                u'width': 190},
#                            {   u'height': 381,
#                                u'legacy': {...},
#                                u'subtype': u'xlarge',
#                                u'type': u'image',
#                                u'url': u'images/2015/10/29/arts/29TVRECAP1/29TVRECAP1-articleLarge-v2.jpg',
#                                u'width': 600},
#                            {   u'height': 75,
#                                u'legacy': {...},
#                                u'subtype': u'thumbnail',
#                                u'type': u'image',
#                                u'url': u'images/2015/10/29/arts/29TVRECAP1/29TVRECAP1-thumbStandard.jpg',
#                                u'width': 75}],
#         u'news_desk': u'Culture',
#         u'print_page': None,
#         u'pub_date': u'2015-12-01T00:00:00Z',
#         u'section_name': u'Arts',
#         u'slideshow_credits': None,
#         u'snippet': u'Sunday\u2019s episode focused on the seemingly boundless bad luck that befalls Matt Jamison.',
#         u'source': u'The New York Times',
#         u'subsection_name': u'Television',
#         u'type_of_material': u'News',
#         u'web_url': u'http://www.nytimes.com/2015/12/01/arts/television/the-leftovers-season-2-episode-5-review.html',
#         u'word_count': u'1076'},
#     {   u'_id': u'564a1455798810390173bb33',
#         u'abstract': None,
#         u'blog': [],
#         u'byline': {   u'original': u'By STEPHANIE ROSENBLOOM',
#                        u'person': [{...}]},
#         u'document_type': u'article',
#         u'headline': {   u'content_kicker': u'The Getaway',
#                          u'kicker': u'The Getaway',
#                          u'main': u'Finding Cheap Flights and More on Black Friday',
#                          u'print_headline': u'When the Presents Come Early: Seasonal Discounts'},
#         u'keywords': [   {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'1',
#                              u'value': u'Travel and Vacations'},
#                          {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'2',
#                              u'value': u'Discount Selling'},
#                          {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'3',
#                              u'value': u'Holidays and Special Occasions'}],
#         u'lead_paragraph': u'In the days following Thanksgiving, scores of travel companies offer discounted hotel rooms, vacation packages, rail passes, rental cars, cruises and flights.',
#         u'multimedia': [   {   u'height': 126,
#                                u'legacy': {...},
#                                u'subtype': u'wide',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/travel/22GETAWAY/22GETAWAY-thumbWide.jpg',
#                                u'width': 190},
#                            {   u'height': 408,
#                                u'legacy': {...},
#                                u'subtype': u'xlarge',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/travel/22GETAWAY/22GETAWAY-articleLarge.jpg',
#                                u'width': 600},
#                            {   u'height': 75,
#                                u'legacy': {...},
#                                u'subtype': u'thumbnail',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/travel/22GETAWAY/22GETAWAY-thumbStandard.jpg',
#                                u'width': 75}],
#         u'news_desk': u'Travel',
#         u'print_page': u'2',
#         u'pub_date': u'2015-11-22T00:00:00Z',
#         u'section_name': u'Travel',
#         u'slideshow_credits': None,
#         u'snippet': u'In the days following Thanksgiving, scores of travel companies offer discounted hotel rooms, vacation packages, rail passes, rental cars, cruises and flights.',
#         u'source': u'The New York Times',
#         u'subsection_name': None,
#         u'type_of_material': u'News',
#         u'web_url': u'http://www.nytimes.com/2015/11/22/travel/black-friday-cyber-monday-cheap-flights.html',
#         u'word_count': u'1242'},
#     {   u'_id': u'5649b034798810095961382d',
#         u'abstract': None,
#         u'blog': [],
#         u'byline': {   u'original': u'By CARINA CHOCANO', u'person': [{...}]},
#         u'document_type': u'article',
#         u'headline': {   u'content_kicker': u'Audiobooks',
#                          u'kicker': u'Audiobooks',
#                          u'main': u'Mindy Kaling\u2019s \u2018Why Not Me?\u2019',
#                          u'print_headline': u'Behind the Laughter'},
#         u'keywords': [   {   u'is_major': u'N',
#                              u'name': u'persons',
#                              u'rank': u'2',
#                              u'value': u'Kaling, Mindy'},
#                          {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'3',
#                              u'value': u'Books and Literature'},
#                          {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'4',
#                              u'value': u'Audiobooks'}],
#         u'lead_paragraph': u'Kaling discusses life in an image-driven industry, and the perks and pitfalls of making it.',
#         u'multimedia': [   {   u'height': 126,
#                                u'legacy': {...},
#                                u'subtype': u'wide',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/books/review/22CHOCANO/22CHOCANO-thumbWide.jpg',
#                                u'width': 190},
#                            {   u'height': 902,
#                                u'legacy': {...},
#                                u'subtype': u'xlarge',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/books/review/22CHOCANO/22CHOCANO-articleLarge.jpg',
#                                u'width': 600},
#                            {   u'height': 75,
#                                u'legacy': {...},
#                                u'subtype': u'thumbnail',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/books/review/22CHOCANO/22CHOCANO-thumbStandard.jpg',
#                                u'width': 75}],
#         u'news_desk': u'BookReview',
#         u'print_page': u'18',
#         u'pub_date': u'2015-11-22T00:00:00Z',
#         u'section_name': u'Books',
#         u'slideshow_credits': None,
#         u'snippet': u'Kaling discusses life in an image-driven industry, and the perks and pitfalls of making it.',
#         u'source': u'The New York Times',
#         u'subsection_name': u'Sunday Book Review',
#         u'type_of_material': u'Review',
#         u'web_url': u'http://www.nytimes.com/2015/11/22/books/review/mindy-kalings-why-not-me.html',
#         u'word_count': u'1210'},
#     {   u'_id': u'5649b035798810095961382e',
#         u'abstract': None,
#         u'blog': [],
#         u'byline': {   u'original': u'By TINA BROWN', u'person': [{...}]},
#         u'document_type': u'article',
#         u'headline': {   u'main': u'\u2018The Blue Touch Paper: A Memoir,\u2019 by David Hare',
#                          u'print_headline': u'A Life of Plenty'},
#         u'keywords': [   {   u'is_major': u'N',
#                              u'name': u'persons',
#                              u'rank': u'2',
#                              u'value': u'Hare, David'},
#                          {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'3',
#                              u'value': u'Books and Literature'},
#                          {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'4',
#                              u'value': u'Theater'}],
#         u'lead_paragraph': u'The playwright David Hare looks back on his experience and his career.',
#         u'multimedia': [   {   u'height': 126,
#                                u'legacy': {...},
#                                u'subtype': u'wide',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/books/review/22BROWN/22BROWN-thumbWide.jpg',
#                                u'width': 190},
#                            {   u'height': 502,
#                                u'legacy': {...},
#                                u'subtype': u'xlarge',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/books/review/22BROWN/22BROWN-articleLarge.jpg',
#                                u'width': 600},
#                            {   u'height': 75,
#                                u'legacy': {...},
#                                u'subtype': u'thumbnail',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/books/review/22BROWN/22BROWN-thumbStandard.jpg',
#                                u'width': 75}],
#         u'news_desk': u'BookReview',
#         u'print_page': u'14',
#         u'pub_date': u'2015-11-22T00:00:00Z',
#         u'section_name': u'Books',
#         u'slideshow_credits': None,
#         u'snippet': u'The playwright David Hare looks back on his experience and his career.',
#         u'source': u'The New York Times',
#         u'subsection_name': u'Sunday Book Review',
#         u'type_of_material': u'Review',
#         u'web_url': u'http://www.nytimes.com/2015/11/22/books/review/the-blue-touch-paper-a-memoir-by-david-hare.html',
#         u'word_count': u'1285'},
#     {   u'_id': u'56462618798810237382f6b5',
#         u'abstract': None,
#         u'blog': [],
#         u'byline': [],
#         u'document_type': u'multimedia',
#         u'headline': {   u'main': u'Mexico\u2019s Roof Dogs'},
#         u'keywords': [   {   u'is_major': u'N',
#                              u'name': u'glocations',
#                              u'rank': u'1',
#                              u'value': u'Mexico'},
#                          {   u'is_major': u'N',
#                              u'name': u'glocations',
#                              u'rank': u'2',
#                              u'value': u'San Miguel de Allende (Mexico)'},
#                          {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'3',
#                              u'value': u'Dogs'},
#                          {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'4',
#                              u'value': u'Roofs'}],
#         u'lead_paragraph': u'The dogs living above San Miguel de Allende, Mexico.',
#         u'multimedia': [   {   u'height': 126,
#                                u'legacy': {...},
#                                u'subtype': u'wide',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/sunday-review/22EXPOSURES-Mexi-roof-dog-slide-6RZP/22EXPOSURES-Mexi-roof-dog-slide-6RZP-thumbWide.jpg',
#                                u'width': 190},
#                            {   u'height': 400,
#                                u'legacy': {...},
#                                u'subtype': u'xlarge',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/sunday-review/22EXPOSURES-Mexi-roof-dog-slide-6RZP/22EXPOSURES-Mexi-roof-dog-slide-6RZP-articleLarge.jpg',
#                                u'width': 600},
#                            {   u'height': 75,
#                                u'legacy': {...},
#                                u'subtype': u'thumbnail',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/sunday-review/22EXPOSURES-Mexi-roof-dog-slide-6RZP/22EXPOSURES-Mexi-roof-dog-slide-6RZP-thumbStandard.jpg',
#                                u'width': 75}],
#         u'news_desk': u'Sunday Review',
#         u'print_page': None,
#         u'pub_date': u'2015-11-22T00:00:00Z',
#         u'section_name': u'Sunday Review',
#         u'slideshow_credits': u'RUSSELL MONK',
#         u'snippet': u'The dogs living above San Miguel de Allende, Mexico.',
#         u'source': u'The New York Times',
#         u'subsection_name': None,
#         u'type_of_material': u'Slideshow',
#         u'web_url': u'http://www.nytimes.com/slideshow/2015/11/22/sunday-review/mexicos-roof-dogs.html',
#         u'word_count': u'9'},
#     {   u'_id': u'56460b127988106302182e25',
#         u'abstract': None,
#         u'blog': [],
#         u'byline': {   u'original': u'By GREGORY COWLES', u'person': [{...}]},
#         u'document_type': u'article',
#         u'headline': {   u'main': u'Inside the List'},
#         u'keywords': [   {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'1',
#                              u'value': u'Books and Literature'}],
#         u'lead_paragraph': u'Donald Trump and Ben Carson are duking it out in the Republican debates \u2014 and on the hardcover nonfiction best-seller list.',
#         u'multimedia': [   {   u'height': 126,
#                                u'legacy': {...},
#                                u'subtype': u'wide',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/books/review/22trump/22trump-thumbWide.jpg',
#                                u'width': 190},
#                            {   u'height': 75,
#                                u'legacy': {...},
#                                u'subtype': u'thumbnail',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/books/review/22trump/22trump-thumbStandard.jpg',
#                                u'width': 75}],
#         u'news_desk': u'BookReview',
#         u'print_page': u'34',
#         u'pub_date': u'2015-11-22T00:00:00Z',
#         u'section_name': u'Books',
#         u'slideshow_credits': None,
#         u'snippet': u'Donald Trump and Ben Carson are duking it out in the Republican debates \u2014 and on the hardcover nonfiction best-seller list.',
#         u'source': u'The New York Times',
#         u'subsection_name': u'Sunday Book Review',
#         u'type_of_material': u'News',
#         u'web_url': u'http://www.nytimes.com/2015/11/22/books/review/inside-the-list.html',
#         u'word_count': u'495'},
#     {   u'_id': u'5644c7457988106302182a28',
#         u'abstract': None,
#         u'blog': [],
#         u'byline': {   u'original': u'By JOHN WILLIAMS', u'person': [{...}]},
#         u'document_type': u'article',
#         u'headline': {   u'content_kicker': u'Audiobooks',
#                          u'kicker': u'Audiobooks',
#                          u'main': u'Elvis Costello\u2019s \u2018Unfaithful Music and Disappearing Ink\u2019',
#                          u'print_headline': u'Extended Play'},
#         u'keywords': [   {   u'is_major': u'N',
#                              u'name': u'creative_works',
#                              u'rank': u'1',
#                              u'value': u'Unfaithful Music & Disappearing Ink (Book)'},
#                          {   u'is_major': u'N',
#                              u'name': u'persons',
#                              u'rank': u'2',
#                              u'value': u'Costello, Elvis'},
#                          {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'3',
#                              u'value': u'Books and Literature'},
#                          {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'4',
#                              u'value': u'Music'},
#                          {   u'is_major': u'N',
#                              u'name': u'subject',
#                              u'rank': u'5',
#                              u'value': u'Rock Music'}],
#         u'lead_paragraph': u'Known for his compact pop lyrics, Elvis Costello spares little in this memoir. ',
#         u'multimedia': [   {   u'height': 126,
#                                u'legacy': {...},
#                                u'subtype': u'wide',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/books/review/22williams-sub/22williams-sub-thumbWide.jpg',
#                                u'width': 190},
#                            {   u'height': 577,
#                                u'legacy': {...},
#                                u'subtype': u'xlarge',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/books/review/22williams-sub/22williams-sub-articleLarge.jpg',
#                                u'width': 600},
#                            {   u'height': 75,
#                                u'legacy': {...},
#                                u'subtype': u'thumbnail',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/22/books/review/22williams-sub/22williams-sub-thumbStandard.jpg',
#                                u'width': 75}],
#         u'news_desk': u'BookReview',
#         u'print_page': u'20',
#         u'pub_date': u'2015-11-22T00:00:00Z',
#         u'section_name': u'Books',
#         u'slideshow_credits': None,
#         u'snippet': u'Known for his compact pop lyrics, Elvis Costello spares little in this memoir.',
#         u'source': u'The New York Times',
#         u'subsection_name': u'Sunday Book Review',
#         u'type_of_material': u'Review',
#         u'web_url': u'http://www.nytimes.com/2015/11/22/books/review/elvis-costellos-unfaithful-music-and-disappearing-ink.html',
#         u'word_count': u'941'},
#     {   u'_id': u'564a2214798810390173bb5e',
#         u'abstract': None,
#         u'blog': [],
#         u'byline': {   u'original': u'Julia Moskin', u'person': [{...}]},
#         u'document_type': u'recipe',
#         u'headline': {   u'main': u'Thanksgiving, the Julia Child Way',
#                          u'name': u'Stuffed Boneless Turkey Breast with White Wine Gravy'},
#         u'keywords': [],
#         u'lead_paragraph': u'Here (at last) is a recipe for roasted turkey breast with the visual impact of a whole bird, complete with mahogany skin and drippings for gravy. The technique of sandwiching a layer of bread stuffing between two boneless turkey breasts is adapted from a recipe by Julia Child. It can be served instead of -- or alongside, if you have a large group -- a traditional Thanksgiving turkey.  \nDon\u2019t fuss overmuch about the assembly.  Even if the stuffing seems to be escaping, or if the shape is more like a football than a turkey, once the roast is wrapped and baked, it will contract into a neat bundle.',
#         u'multimedia': [   {   u'credit': u'Francesco Tonelli for The New York Times',
#                                u'height': 75,
#                                u'legacy': [],
#                                u'rank': u'1',
#                                u'subtype': u'thumbnail',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/18/dining/18JULIAREX1/18JULIAREX1-thumbStandard.jpg',
#                                u'width': 75},
#                            {   u'credit': u'Francesco Tonelli for The New York Times',
#                                u'height': 556,
#                                u'legacy': [],
#                                u'rank': u'1',
#                                u'subtype': u'large',
#                                u'type': u'image',
#                                u'url': u'images/2015/11/18/dining/18JULIAREX1/18JULIAREX1-articleLarge.jpg',
#                                u'width': 600}],
#         u'news_desk': None,
#         u'print_page': None,
#         u'pub_date': u'2015-11-18T00:00:00Z',
#         u'section_name': None,
#         u'slideshow_credits': None,
#         u'snippet': u'Here (at last) is a recipe for roasted turkey breast with the visual impact of a whole bird, complete with mahogany skin and drippings for gravy. The technique of sandwiching a layer of bread stuffing between two boneless turkey breasts is adapted...',
#         u'source': u'du_recipe',
#         u'subsection_name': None,
#         u'type_of_material': u'Recipe',
#         u'web_url': u'http://cooking.nytimes.com/recipes/1017818-stuffed-boneless-turkey-breast-with-white-wine-gravy',
#         u'word_count': u'689'}]

# %%
from pymongo import

# %%
link = 'http://api.nytimes.com/svc/search/v2/articlesearch.json'
payload = {'api-key': 'c6fa025637d249e0133e3a71d747c378:15:73486130'}
html_str = single_query(link, payload)

# %%
client = MongoClient()

# %%
nytdb = client['nytb']
articles = nytdb['articles']

# %%
articles.insert_many(arts)

# %%
def paginated_query(base_link, payload, i):
    link = base_link + '?sort=newest' + '&page=' + str(idx)
    response = requests.get(link, params=payload)
    if response.status_code != 200:
        print 'WARNING', response.status_code
    else:
        return response.json()

# %%
t_arts = []
for idx in range(2):
    t_arts.append(paginated_query(link, payload, idx))
# Out:
# WARNING 400
# WARNING 400

# %% [markdown]
# ## Part 4: Scraping using the meta data

# %% [markdown]
# **At this point:**
# - **We have successful gathered article metadata from the NYT API**
# - **We have stored said data in MongoDB**
# - **We have URLs for each article that we can now use for scraping**
#
# 1. Now that we have all the meta data, it it time to get the article content!  We will be doing something
#    I call a data join (some people call it [data blending](http://www.tableausoftware.com/videos/data-integration)... but they charge you money so they can call it that).
#     * Iterate over your collection in your database.  For all the articles for which you do not have HTML content
#       (this will be all of them to begin with), use the 'web url' in the meta data to make a web request.
#
#     * Use Beautiful Soup to parse the returned HTML. Make sure to initialize `soup` with:
#       `soup = BeautifulSoup(response.text, 'html.parser')`
#
#     * Add a new field in the meta data records in your Mongo database to store the raw HTML from the web page.
#
#     * Find the CSS selectors that would allow you to extract article text in the web pages. You can use the Chrome
#       DevTools to help you find the relevant CSS Selectors. If you are having problems such as
#       `$ is not a function`. Use the following script to load in the jQuery library and then try again.
#
#       ```js
#       var jq = document.createElement('script');
#       jq.src = "https://ajax.googleapis.com/ajax/libs/jquery/1/jquery.min.js";
#       document.getElementsByTagName('head')[0].appendChild(jq);
#       ```
#
#     * Use `soup.select(Your CSS Selector)` to extract article text from the web pages.
#
#     * Add a new field in the meta data records in your Mongo database to store the text of the articles.
#
#
# You have made it to the end (hopefully successfully).  Now that you have your data and have contextualized it with information from the web, you can start performing some interesting analyses on it.

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# ### User Login

# %% [markdown]
# Scraping sites is easy when you can have clear access to the content and it is in a semi-structured form.  One issue that arises with scraping sites is the need to login.
#
# 1. Find a site that you might want to get data from that requires a login.
#
# * Use a [requests session](http://docs.python-requests.org/en/latest/user/advanced/) to login to a site to scrape.
# * Example code in [web_scraping.ipynb](web_scraping.ipynb)

# %% [markdown]
# ### Client side templating

# %% [markdown]
# Some sites do what is called [client side templating](http://www.smashingmagazine.com/2012/12/05/client-side-templating/), basically you send only data from the server and write a bunch of Javascript to dynamically write HTML when the page loads.
#
# 1. Find a site that templates on the client.
# 2. Look at the [Chrome Developer Tools](http://thewc.co/articles/view/web-inspector-tutorial) to find which "Resource" the data came in. __Hint Hint, look for a JSON file__

# %% [markdown]
# ### Automated Scraper

# %% [markdown]
# Scraping the web from your laptop is great, but what if you want to automate things and have a long running process (scraping for days...)?  A common solution is to setup a script that continuous scrapes the web from a hosted virtual server on something like Amazon Web Service (AWS).
#
# 1. Follow along on the auxiliary AWS sprint here: [https://github.com/zipfian/aws-and-the-cloud](https://github.com/zipfian/aws-and-the-cloud#assignment)
# 2. Setup an automated scraper on AWS using [cron](http://www.unixgeeks.org/security/newbie/unix/cron-1.html) or a [python scheduler](https://github.com/dbader/schedule)
# 3. Save the scraped files to [S3](http://aws.amazon.com/s3/) or a database.

# %% [markdown]
# ### Proxy

# %% [markdown]
# Some sites block IPs from know bad actors.  LinkedIn actually does this for any Amazon Web Services (AWS) IP address.  But us being the smart data scientists we are, we will devise a solution!
#
# ![](http://nickcavarretta.com.au/shitzu/uploads/2013/09/Scrape-all-the-things-300x225.png)
#
# [Tor](https://www.torproject.org/) is a lovely community built around anonymization on the web.  Tor allows for users to browse the web anonymously by daisy chaining a request across a network of nodes to hide the origin IP of the request.
#
# ![tor](http://upload.wikimedia.org/wikipedia/commons/d/dc/Tor-onion-network.png)
#
# 1. Using Tor and its [Python client](https://stem.torproject.org/tutorials.html), try to setup a scraper that is anonymized.  Bonus points if you host your scraper on AWS and successful can scrape LinkedIn profile pages.
